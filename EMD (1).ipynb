# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=dfedb87132fd900bf6f360c1565917f7219f421f54017c4141d5f23327083226
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
import pyspark
from pyspark.sql import SQLContext
from pyspark import SparkContext
sc =SparkContext.getOrCreate()
sqlContext = SQLContext(sc)
df = sqlContext.read.csv("/Users/kedarpandya/Desktop/Acedamics/University_of_Windsor/COMP_8390-1_ENTDBS/Final_Project/pollution_us_2000_2016 (1).csv", header=True)
# df.printSchema()
df.registerTempTable("Pollution")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-67d6e50d2ad2> in <cell line: 1>()
# ----> 1 import pyspark
#       2 from pyspark.sql import SQLContext
#       3 from pyspark import SparkContext
#       4 sc =SparkContext.getOrCreate()
#       5 sqlContext = SQLContext(sc)
#
# ModuleNotFoundError: No module named 'pyspark'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
from datetime import datetime
from pyspark.sql.functions import col, udf
from pyspark.sql.types import DateType
# converting the date from string to DateTime format using UDF
func =  udf (lambda x: datetime.strptime(x, '%Y-%m-%d'), DateType())
df_new = df.withColumn('Date', func(col('Date Local')))

# %%
from pyspark.sql.types import DoubleType
df_new = df_new.withColumn("N02AQI", df_new["NO2 AQI"].cast(DoubleType()))
df_new = df_new.withColumn("SO2 AQI", df_new["SO2 AQI"].cast(DoubleType()))
df_new = df_new.withColumn("CO AQI", df_new["CO AQI"].cast(DoubleType()))
df_new = df_new.withColumn("O3 AQI", df_new["O3 AQI"].cast(DoubleType()))
df_new.registerTempTable("Pollution_Data")

# %%
q2 = sqlContext.sql("SELECT MAX(`NO2 AQI`) as Max_NO2 , MAX(`SO2 AQI`) as SO2_AQI, City,Year(Date) as Yearly FROM Pollution_Data GROUP BY Day(Date),City,Year(Date) ORDER BY City,YEAR(Date)")
q2.registerTempTable('q2')

# %%
q2_sub = sqlContext.sql("SELECT MAX(Max_NO2) as x, MAX(SO2_AQI) as SO2_AQI, City, Yearly FROM q2 GROUP BY Yearly, City ORDER BY Yearly,City")
q2_sub.registerTempTable("q2_sub")

# %%
sqlContext.sql("SELECT Yearly, count(City) FROM q2_sub WHERE x >80 OR SO2_AQI>80 GROUP BY Yearly ORDER BY Yearly").show(100)
# Out:
# +------+-----------+
# |Yearly|count(City)|
# +------+-----------+
# |  2000|         52|
# |  2001|         41|
# |  2002|         42|
# |  2003|         41|
# |  2004|         35|
# |  2005|         34|
# |  2006|         39|
# |  2007|         34|
# |  2008|         29|
# |  2009|         20|
# |  2010|         12|
# |  2011|         14|
# |  2012|         13|
# |  2013|          7|
# |  2014|         13|
# |  2015|         10|
# |  2016|          3|
# +------+-----------+

# %%
sqlContext.sql("SELECT City, Yearly FROM q2_sub WHERE Yearly=2016 AND x >80 OR SO2_AQI>80").show(20)
# Out:
# +--------------------+------+
# |                City|Yearly|
# +--------------------+------+
# |          Alexandria|  2000|
# |             Ashland|  2000|
# |         Baton Rouge|  2000|
# |        Beaver Falls|  2000|
# |             Bristol|  2000|
# |Calumet City (PU ...|  2000|
# |              Camden|  2000|
# |           Charleroi|  2000|
# |           Charlotte|  2000|
# |             Chicago|  2000|
# |             Detroit|  2000|
# |            Ferguson|  2000|
# |          Greensburg|  2000|
# |           Hawthorne|  2000|
# |           Henderson|  2000|
# |          Holtsville|  2000|
# |             Houston|  2000|
# |Indianapolis (Rem...|  2000|
# |           Johnstown|  2000|
# |         Kansas City|  2000|
# +--------------------+------+
# only showing top 20 rows

# %%
sqlContext.sql(" SELECT State, City, MAX(`NO2 AQI`) as Max_NO2_AQI ,
MAX(`SO2 AQI`) AS MAX_SO2_AQI, MAX(`O3 AQI`) AS O3_AQI,
               MAX(`NO2 AQI`) AS NO2_AQI, YEAR(Date) as Yearly
               FROM Pollution_Data
               WHERE `O3 AQI` > 80 AND
               `SO2 AQI`>80 AND
               `NO2 AQI`>80
               GROUP BY YEAR(Date),State,City
               ORDER BY  YEAR(Date)").show(100)
# Out:
# +------+-----------+-----------+-----------+------+-------+------+
# | State|       City|Max_NO2_AQI|MAX_SO2_AQI|O3_AQI|NO2_AQI|Yearly|
# +------+-----------+-----------+-----------+------+-------+------+
# | Texas|    Houston|        101|       86.0| 150.0|    101|  2000|
# |Kansas|Kansas City|        103|       97.0| 200.0|    103|  2005|
# +------+-----------+-----------+-----------+------+-------+------+

# %%
sqlContext.sql(" SELECT State, City, MAX(`SO2 AQI`) as Max_SO2_AQI , MAX(`O3 AQI`) AS MAX_O3_AQI, MAX(`CO AQI`) AS CO_AQI, MAX(`NO2 AQI`) AS NO2_AQI, YEAR(Date) as Yearly FROM Pollution_Data WHERE `O3 AQI` > 80 AND `SO2 AQI`>80 AND `CO AQI`>80 GROUP BY YEAR(Date),State,City ORDER BY  YEAR(Date)").show(100)
# Out:
# +-----+----+-----------+----------+------+-------+------+
# |State|City|Max_SO2_AQI|MAX_O3_AQI|CO_AQI|NO2_AQI|Yearly|
# +-----+----+-----------+----------+------+-------+------+
# +-----+----+-----------+----------+------+-------+------+

# %%
most_polluted_cities_yearly =sqlContext.sql("SELECT State, City, MAX(`N02AQI`) as Max_NO2_AQI , YEAR(Date) as Yearly FROM Pollution_Data WHERE `N02AQI`>80 GROUP BY YEAR(Date),City,State ORDER BY  YEAR(Date),MAX(`N02AQI`) DESC")
most_polluted_cities_yearly.registerTempTable("most_polluted_cities_yearly")

# %%
sqlContext.sql("SELECT State,City, MAX(`N02AQI`) as Max_NO2_AQI ,
MAX(`SO2 AQI`) as Max_SO2_AQI , MAX(`O3 AQI`) AS MAX_O3_AQI,
               MAX(`CO AQI`) AS CO_AQI, YEAR(Date) as Yearly
               FROM Pollution_Data GROUP BY YEAR(Date),City,State
               ORDER BY  YEAR(Date)").show(30)
# Out:
# +------------+--------------------+-----------+-----------+----------+------+------+
# |       State|                City|Max_NO2_AQI|Max_SO2_AQI|MAX_O3_AQI|CO_AQI|Yearly|
# +------------+--------------------+-----------+-----------+----------+------+------+
# |  California|           Davenport|       33.0|       33.0|      47.0|   9.0|  2000|
# |  California|          Costa Mesa|      102.0|       29.0|     127.0|  69.0|  2000|
# |    Missouri|             St. Ann|       84.0|       91.0|     142.0|  22.0|  2000|
# |  California|           San Pablo|       64.0|       39.0|      74.0|  22.0|  2000|
# |Pennsylvania|             Reading|       57.0|      135.0|     172.0|  22.0|  2000|
# |Pennsylvania|          Greensburg|       49.0|      110.0|     145.0|  17.0|  2000|
# |    Missouri|           St. Louis|       80.0|      103.0|     140.0|  52.0|  2000|
# |  California|            Rubidoux|       94.0|      115.0|     192.0|  48.0|  2000|
# |Pennsylvania|                York|       63.0|      104.0|     177.0|  22.0|  2000|
# |    Illinois|             Chicago|       97.0|      102.0|      42.0|  26.0|  2000|
# |  California|           Pittsburg|       51.0|       40.0|     111.0|  28.0|  2000|
# |Pennsylvania|          Pittsburgh|       74.0|      117.0|     169.0|  18.0|  2000|
# |  New Jersey|              Camden|       97.0|       91.0|     203.0|  51.0|  2000|
# |  California|Vandenberg Air Fo...|       31.0|        6.0|      80.0|   6.0|  2000|
# |    Oklahoma|           Park Hill|       48.0|       86.0|     145.0|   6.0|  2000|
# |      Kansas|         Kansas City|       74.0|      101.0|     132.0|  57.0|  2000|
# |    Kentucky|             Paducah|       62.0|       43.0|     179.0|  20.0|  2000|
# |    New York|          Holtsville|       67.0|       86.0|     203.0|  32.0|  2000|
# |  California|        Arden-Arcade|       60.0|       33.0|     161.0|  52.0|  2000|
# |    Virginia|          Alexandria|       74.0|      109.0|     150.0|  25.0|  2000|
# |Pennsylvania|          New Castle|       65.0|      124.0|     100.0|  19.0|  2000|
# |Pennsylvania|           Lancaster|       55.0|       79.0|     177.0|  19.0|  2000|
# |    Virginia|       Not in a city|       45.0|       60.0|     147.0|  20.0|  2000|
# |  California|          Long Beach|      108.0|       65.0|     114.0|  63.0|  2000|
# |  California|              Lompoc|       42.0|       10.0|      74.0|  17.0|  2000|
# |    Illinois|              Cicero|       84.0|       79.0|      87.0|  38.0|  2000|
# |    Virginia|              McLean|       72.0|       81.0|     164.0|  43.0|  2000|
# |    Illinois|Calumet City (PU ...|       58.0|      136.0|     101.0|  24.0|  2000|
# |    Kentucky|           Henderson|       71.0|      136.0|     122.0|  17.0|  2000|
# |  California|            Calexico|      118.0|       37.0|     195.0| 201.0|  2000|
# +------------+--------------------+-----------+-----------+----------+------+------+
# only showing top 30 rows

# %%
t1=sqlContext.sql("SELECT State,City, MAX(`N02AQI`) as Max_NO2_AQI , MAX(`SO2 AQI`) as Max_SO2_AQI , MAX(`O3 AQI`) AS MAX_O3_AQI, MAX(`CO AQI`) AS Max_CO_AQI, YEAR(Date) as Yearly FROM Pollution_Data GROUP BY YEAR(Date),City,State ORDER BY  YEAR(Date)")
t1.registerTempTable("Entire_Pollution")

# %%
Top_polluted_cities=sqlContext.sql("SELECT State,City,COUNT(Yearly) as Count  FROM most_polluted_cities_yearly GROUP BY City,State ORDER BY COUNT(Yearly) DESC LIMIT 10")
Top_polluted_cities.registerTempTable("Top_polluted_cities")
Top_polluted_cities.show(20)
# Out:
# +--------------------+------------+-----+
# |               State|        City|Count|
# +--------------------+------------+-----+
# |          California|    Calexico|   16|
# |          California| Los Angeles|   15|
# |          California|  Long Beach|   14|
# |            New York|    New York|   13|
# |District Of Columbia|  Washington|   11|
# |          California|   San Diego|   11|
# |            Colorado|       Welby|   11|
# |          California|     Burbank|   11|
# |        Pennsylvania|Philadelphia|   10|
# |               Texas|     El Paso|   10|
# +--------------------+------------+-----+

# %%
table_state=sqlContext.sql("SELECT Top_polluted_cities.City as City, Top_polluted_cities.State as State, most_polluted_cities_yearly.Max_NO2_AQI, most_polluted_cities_yearly.Yearly  as Yearly FROM Top_polluted_cities JOIN most_polluted_cities_yearly ON Top_polluted_cities.City=most_polluted_cities_yearly.City GROUP BY Top_polluted_cities.`City`,most_polluted_cities_yearly.Max_NO2_AQI,most_polluted_cities_yearly.Yearly ,Top_polluted_cities.`State` ORDER BY Top_polluted_cities.`City`,most_polluted_cities_yearly.Yearly  ")
table_state.toPandas().to_csv("State_Polluted_Data.csv")

# %%
table=sqlContext.sql("SELECT Top_polluted_cities.City as City, most_polluted_cities_yearly.Max_NO2_AQI, most_polluted_cities_yearly.Yearly  as Yearly FROM Top_polluted_cities JOIN most_polluted_cities_yearly ON Top_polluted_cities.City=most_polluted_cities_yearly.City GROUP BY Top_polluted_cities.`City`,most_polluted_cities_yearly.Max_NO2_AQI,most_polluted_cities_yearly.Yearly  ORDER BY Top_polluted_cities.`City`,most_polluted_cities_yearly.Yearly  ")
table.show()
table.registerTempTable("Final_Table")
table.toPandas().to_csv("Non_Pivoted_Table.csv")
# Out:
# +--------+-----------+------+
# |    City|Max_NO2_AQI|Yearly|
# +--------+-----------+------+
# | Burbank|      113.0|  2000|
# | Burbank|      129.0|  2001|
# | Burbank|      131.0|  2002|
# | Burbank|      108.0|  2003|
# | Burbank|      105.0|  2004|
# | Burbank|       88.0|  2005|
# | Burbank|      101.0|  2006|
# | Burbank|       86.0|  2007|
# | Burbank|      102.0|  2008|
# | Burbank|       87.0|  2009|
# | Burbank|       81.0|  2010|
# |Calexico|      118.0|  2000|
# |Calexico|      108.0|  2001|
# |Calexico|      108.0|  2002|
# |Calexico|      111.0|  2003|
# |Calexico|      102.0|  2004|
# |Calexico|      107.0|  2005|
# |Calexico|      101.0|  2006|
# |Calexico|      102.0|  2007|
# |Calexico|      110.0|  2008|
# +--------+-----------+------+
# only showing top 20 rows
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py:329: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)

# %%
table=table.toPandas()

# %%
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
table=table.pivot(index= 'Yearly',columns='City', values='Max_NO2_AQI')
table
# Out:
# City    Burbank  Calexico  El Paso  Long Beach  Los Angeles  New York  \
# Yearly
# 2000      113.0     118.0     99.0       108.0        111.0     101.0
# 2001      129.0     108.0    101.0       105.0        112.0     102.0
# 2002      131.0     108.0    111.0       106.0        112.0     102.0
# 2003      108.0     111.0    100.0       107.0        113.0     105.0
# 2004      105.0     102.0     81.0       105.0        112.0     109.0
# 2005       88.0     107.0     82.0       108.0        106.0      91.0
# 2006      101.0     101.0    103.0       101.0        103.0      91.0
# 2007       86.0     102.0     89.0       102.0        102.0     101.0
# 2008      102.0     110.0     88.0       106.0        105.0      82.0
# 2009       87.0     101.0      NaN       103.0        104.0      95.0
# 2010       81.0       NaN      NaN       104.0         88.0     102.0
# 2011        NaN     106.0      NaN       102.0        103.0       NaN
# 2012        NaN      90.0      NaN        97.0          NaN       NaN
# 2013        NaN     111.0      NaN         NaN         89.0       NaN
# 2014        NaN      93.0      NaN       107.0         86.0       NaN
# 2015        NaN      82.0     93.0         NaN         86.0      97.0
# 2016        NaN      83.0      NaN         NaN          NaN      88.0
#
# City    Philadelphia  San Diego  Washington  Welby
# Yearly
# 2000            95.0      104.0       109.0  109.0
# 2001            87.0      110.0        88.0  102.0
# 2002            85.0      106.0       101.0    NaN
# 2003           100.0      110.0       101.0  108.0
# 2004           101.0      106.0       104.0  103.0
# 2005            85.0      103.0       104.0   96.0
# 2006           102.0       97.0       104.0   89.0
# 2007            87.0      101.0        81.0  103.0
# 2008             NaN      105.0       101.0   84.0
# 2009             NaN       90.0        82.0   83.0
# 2010           106.0       82.0        85.0    NaN
# 2011            86.0        NaN         NaN    NaN
# 2012             NaN        NaN         NaN    NaN
# 2013             NaN        NaN         NaN   87.0
# 2014             NaN        NaN         NaN  102.0
# 2015             NaN        NaN         NaN    NaN
# 2016             NaN        NaN         NaN    NaN

# %%
import numpy as np
for city in list(table):
    means=np.nanmean(table[city])
    table[city].fillna(means,inplace=True)

# %%
table
table.astype('float64')
# Out:
# City       Burbank  Calexico  El Paso  Long Beach  Los Angeles    New York  \
# Yearly
# 2000    113.000000  118.0000     99.0  108.000000   111.000000  101.000000
# 2001    129.000000  108.0000    101.0  105.000000   112.000000  102.000000
# 2002    131.000000  108.0000    111.0  106.000000   112.000000  102.000000
# 2003    108.000000  111.0000    100.0  107.000000   113.000000  105.000000
# 2004    105.000000  102.0000     81.0  105.000000   112.000000  109.000000
# 2005     88.000000  107.0000     82.0  108.000000   106.000000   91.000000
# 2006    101.000000  101.0000    103.0  101.000000   103.000000   91.000000
# 2007     86.000000  102.0000     89.0  102.000000   102.000000  101.000000
# 2008    102.000000  110.0000     88.0  106.000000   105.000000   82.000000
# 2009     87.000000  101.0000     94.7  103.000000   104.000000   95.000000
# 2010     81.000000  102.0625     94.7  104.000000    88.000000  102.000000
# 2011    102.818182  106.0000     94.7  102.000000   103.000000   97.384615
# 2012    102.818182   90.0000     94.7   97.000000   102.133333   97.384615
# 2013    102.818182  111.0000     94.7  104.357143    89.000000   97.384615
# 2014    102.818182   93.0000     94.7  107.000000    86.000000   97.384615
# 2015    102.818182   82.0000     93.0  104.357143    86.000000   97.000000
# 2016    102.818182   83.0000     94.7  104.357143   102.133333   88.000000
#
# City    Philadelphia   San Diego  Washington       Welby
# Yearly
# 2000            95.0  104.000000  109.000000  109.000000
# 2001            87.0  110.000000   88.000000  102.000000
# 2002            85.0  106.000000  101.000000   96.909091
# 2003           100.0  110.000000  101.000000  108.000000
# 2004           101.0  106.000000  104.000000  103.000000
# 2005            85.0  103.000000  104.000000   96.000000
# 2006           102.0   97.000000  104.000000   89.000000
# 2007            87.0  101.000000   81.000000  103.000000
# 2008            93.4  105.000000  101.000000   84.000000
# 2009            93.4   90.000000   82.000000   83.000000
# 2010           106.0   82.000000   85.000000   96.909091
# 2011            86.0  101.272727   96.363636   96.909091
# 2012            93.4  101.272727   96.363636   96.909091
# 2013            93.4  101.272727   96.363636   87.000000
# 2014            93.4  101.272727   96.363636  102.000000
# 2015            93.4  101.272727   96.363636   96.909091
# 2016            93.4  101.272727   96.363636   96.909091

# %%
table.to_csv("Polluted_cities_NO2AQI.csv")

# %%
df_new
# Out:
# DataFrame[_c0: string, State Code: string, County Code: string, Site Num: string, Address: string, State: string, County: string, City: string, Date Local: string, NO2 Units: string, NO2 Mean: string, NO2 1st Max Value: string, NO2 1st Max Hour: string, NO2 AQI: string, O3 Units: string, O3 Mean: string, O3 1st Max Value: string, O3 1st Max Hour: string, O3 AQI: double, SO2 Units: string, SO2 Mean: string, SO2 1st Max Value: string, SO2 1st Max Hour: string, SO2 AQI: double, CO Units: string, CO Mean: string, CO 1st Max Value: string, CO 1st Max Hour: string, CO AQI: double, Date: date, N02AQI: double]

# %% [markdown]
# <h3> <font color='green'> Linking the Pollution Dataset with the Land Temperature Data set.</font> </h3>

# %%
sc =SparkContext.getOrCreate()
sqlContext = SQLContext(sc)
df = sqlContext.read.csv("/content/drive/MyDrive/GlobalLandTemperaturesByCity.csv", header=True)

# %%
func =  udf (lambda x: datetime.strptime(x, '%Y-%m-%d'), DateType())
df = df.withColumn('Dt', func(col('dt')))
df.registerTempTable("City_Data")
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py:329: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)

# %%
df.show(10)
# Out:
# +----------+------------------+-----------------------------+-----+-------+--------+---------+
# |        Dt|AverageTemperature|AverageTemperatureUncertainty| City|Country|Latitude|Longitude|
# +----------+------------------+-----------------------------+-----+-------+--------+---------+
# |1743-11-01|             6.068|           1.7369999999999999|Århus|Denmark|  57.05N|   10.33E|
# |1743-12-01|              NULL|                         NULL|Århus|Denmark|  57.05N|   10.33E|
# |1744-01-01|              NULL|                         NULL|Århus|Denmark|  57.05N|   10.33E|
# |1744-02-01|              NULL|                         NULL|Århus|Denmark|  57.05N|   10.33E|
# |1744-03-01|              NULL|                         NULL|Århus|Denmark|  57.05N|   10.33E|
# |1744-04-01|5.7879999999999985|           3.6239999999999997|Århus|Denmark|  57.05N|   10.33E|
# |1744-05-01|            10.644|           1.2830000000000001|Århus|Denmark|  57.05N|   10.33E|
# |1744-06-01|14.050999999999998|                        1.347|Århus|Denmark|  57.05N|   10.33E|
# |1744-07-01|            16.082|                        1.396|Århus|Denmark|  57.05N|   10.33E|
# |1744-08-01|              NULL|                         NULL|Århus|Denmark|  57.05N|   10.33E|
# +----------+------------------+-----------------------------+-----+-------+--------+---------+
# only showing top 10 rows

# %%
table34=sqlContext.sql("SELECT  City, MAX(`N02AQI`) as Max_NO2_AQI , MAX(`SO2 AQI`) as Max_SO2_AQI, MAX(`CO AQI`) as Max_CO_AQI, MAX(`O3 AQI`) as Max_O3_AQI , first(Date) AS Year FROM Pollution_Data  GROUP BY YEAR(Date) , City ORDER BY YEAR(Date), City")
table34.registerTempTable("Polls")

# %%
table34=sqlContext.sql("SELECT  City, MAX(`N02AQI`) as Max_NO2_AQI , MAX(`SO2 AQI`) as Max_SO2_AQI, MAX(`CO AQI`) as Max_CO_AQI, MAX(`O3 AQI`) as Max_O3_AQI , first(Date) AS Year FROM Pollution_Data  GROUP BY YEAR(Date) , City ORDER BY YEAR(Date), City")
table34.registerTempTable("Polls")

# %%
sqlContext.sql(" SELECT YEAR(Dt),City, AVG(AverageTemperature) AS Yearly_Avg_Temp FROM City_Data GROUP BY YEAR(Dt), City").show()
# Out:
# +--------+---------+------------------+
# |year(Dt)|     City|   Yearly_Avg_Temp|
# +--------+---------+------------------+
# |    1767|    Århus| 6.946416666666668|
# |    1781|    Århus| 8.528916666666667|
# |    1766|    Çorlu|          13.39575|
# |    1868|    Çorlu|           13.0665|
# |    1938|  Öskemen|1.3139999999999992|
# |    1988|  Öskemen|2.1085000000000007|
# |    1994| A Coruña|13.764333333333335|
# |    1840|   Aachen|7.8524166666666675|
# |    1840|  Aalborg| 6.725416666666667|
# |    1863|  Aalborg| 8.568416666666666|
# |    1880|      Aba|25.996166666666667|
# |    1888|      Aba|25.647000000000002|
# |    1900|      Aba|26.418833333333335|
# |    1917|      Aba| 26.94966666666667|
# |    1932|      Aba|26.749749999999995|
# |    1914|Abakaliki|26.909999999999997|
# |    1838|   Abakan|-1.885833333333333|
# |    1914|   Abakan|0.2978333333333338|
# |    1979|   Abakan|0.6380833333333328|
# |    1860| Aberdeen| 6.903583333333333|
# +--------+---------+------------------+
# only showing top 20 rows

# %%
table123=sqlContext.sql(" SELECT YEAR(Dt) as Years,City, AVG(AverageTemperature) AS Yearly_Avg_Temp FROM City_Data GROUP BY YEAR(Dt), City")
table123.registerTempTable("City_Temp")

# %%
sqlContext.sql("SELECT Polls.City, Max(Polls.Max_NO2_AQI) ,Max(Polls.Max_SO2_AQI),Polls.Max_CO_AQI,Polls.Max_O3_AQI, Polls.Year FROM Polls JOIN City_Temp ON YEAR(Polls.Year)==City_Temp.Years AND Polls.City==City_Temp.City Group by City_Temp.Years, Polls.City, Polls.Max_NO2_AQI, Polls.Max_SO2_AQI, Polls.Max_CO_AQI,Polls.Max_O3_AQI, Polls.Year ORDER BY Polls.Year, Polls.City ").show(100)
# Out:
# +-------------+----------------+----------------+----------+----------+----------+
# |         City|max(Max_NO2_AQI)|max(Max_SO2_AQI)|Max_CO_AQI|Max_O3_AQI|      Year|
# +-------------+----------------+----------------+----------+----------+----------+
# |  Baton Rouge|            94.0|            99.0|      48.0|     187.0|2000-01-01|
# |      Burbank|           113.0|            14.0|      68.0|     202.0|2000-01-01|
# |  Chula Vista|            70.0|            62.0|      35.0|     104.0|2000-01-01|
# |      Concord|            72.0|            29.0|      31.0|     147.0|2000-01-01|
# |   Costa Mesa|           102.0|            29.0|      69.0|     127.0|2000-01-01|
# |       Dallas|            97.0|            19.0|      25.0|     177.0|2000-01-01|
# |      Houston|           101.0|           172.0|      42.0|     203.0|2000-01-01|
# |  Kansas City|            74.0|           101.0|      57.0|     132.0|2000-01-01|
# |   Long Beach|           108.0|            65.0|      63.0|     114.0|2000-01-01|
# | Philadelphia|            95.0|            89.0|      51.0|     140.0|2000-01-01|
# |      Phoenix|           105.0|            41.0|      59.0|     132.0|2000-01-01|
# |    San Diego|           104.0|            79.0|      65.0|     109.0|2000-01-01|
# |San Francisco|            72.0|            27.0|      36.0|      36.0|2000-01-01|
# |    San Pablo|            64.0|            39.0|      22.0|      74.0|2000-01-01|
# |   Scottsdale|           132.0|            31.0|      38.0|     106.0|2000-01-01|
# |       Tucson|            73.0|            27.0|      31.0|     109.0|2000-01-01|
# |      Vallejo|            62.0|            24.0|      57.0|      47.0|2000-01-01|
# |   Washington|           109.0|           104.0|      58.0|     164.0|2000-01-01|
# |      Chicago|            97.0|           102.0|      26.0|      42.0|2000-01-06|
# |      El Paso|            99.0|            50.0|      49.0|     154.0|2000-01-06|
# |    Henderson|            71.0|           136.0|      17.0|     122.0|2000-02-29|
# |  Los Angeles|           111.0|           100.0|      66.0|     169.0|2000-03-01|
# |   Louisville|            58.0|           128.0|      20.0|     129.0|2000-03-21|
# |   Alexandria|            74.0|           109.0|      25.0|     150.0|2000-03-31|
# |      Bristol|            64.0|            82.0|      19.0|     207.0|2000-03-31|
# |    Charleroi|            43.0|           110.0|      11.0|     169.0|2000-03-31|
# |    Charlotte|            74.0|            92.0|      42.0|     205.0|2000-03-31|
# |      Detroit|            93.0|           134.0|      51.0|     114.0|2000-03-31|
# |    Lancaster|            55.0|            79.0|      19.0|     177.0|2000-03-31|
# |   Pittsburgh|            74.0|           117.0|      18.0|     169.0|2000-03-31|
# |      Reading|            57.0|           135.0|      22.0|     172.0|2000-03-31|
# |         York|            63.0|           104.0|      22.0|     177.0|2000-03-31|
# |     New York|           101.0|           105.0|      55.0|     201.0|2000-05-05|
# |  Bakersfield|            88.0|            17.0|      43.0|      40.0|2000-11-01|
# |  Bakersfield|           104.0|            43.0|      39.0|      80.0|2001-01-01|
# |  Baton Rouge|            73.0|           111.0|      62.0|     150.0|2001-01-01|
# |      Burbank|           129.0|            19.0|      56.0|     172.0|2001-01-01|
# |  Chula Vista|            69.0|            67.0|      53.0|     109.0|2001-01-01|
# |      Concord|            63.0|            33.0|      31.0|     129.0|2001-01-01|
# |   Costa Mesa|            81.0|            19.0|      52.0|      93.0|2001-01-01|
# |       Dallas|            72.0|            21.0|      28.0|     192.0|2001-01-01|
# |      El Paso|           101.0|            33.0|      59.0|     137.0|2001-01-01|
# |      Houston|           106.0|           135.0|      28.0|     204.0|2001-01-01|
# |  Kansas City|            71.0|            79.0|      47.0|     119.0|2001-01-01|
# |   Long Beach|           105.0|            65.0|      53.0|      84.0|2001-01-01|
# |        Miami|            44.0|            70.0|       3.0|     127.0|2001-01-01|
# |     New York|           102.0|           105.0|      42.0|     166.0|2001-01-01|
# | Philadelphia|            87.0|            72.0|      49.0|     106.0|2001-01-01|
# |      Phoenix|            94.0|            26.0|      49.0|     104.0|2001-01-01|
# |    San Diego|           110.0|            81.0|      55.0|      97.0|2001-01-01|
# |San Francisco|            71.0|            36.0|      38.0|      46.0|2001-01-01|
# |    San Pablo|            58.0|            19.0|      16.0|     100.0|2001-01-01|
# |   Scottsdale|            76.0|            13.0|      36.0|      77.0|2001-01-01|
# |       Tucson|            57.0|            14.0|      22.0|     100.0|2001-01-01|
# |      Vallejo|            54.0|            23.0|      47.0|      80.0|2001-01-01|
# |   Washington|            88.0|           122.0|      54.0|     164.0|2001-01-01|
# |    Henderson|            70.0|           126.0|      15.0|     104.0|2001-02-28|
# |   Louisville|            57.0|           137.0|      18.0|     127.0|2001-02-28|
# |  Los Angeles|           112.0|            36.0|      62.0|     159.0|2001-03-03|
# |      Bristol|            71.0|            51.0|      23.0|     202.0|2001-03-31|
# |    Charleroi|            42.0|           122.0|       5.0|     137.0|2001-03-31|
# |    Charlotte|            67.0|           132.0|      27.0|     177.0|2001-03-31|
# |      Detroit|            72.0|           161.0|      28.0|     142.0|2001-03-31|
# |    Lancaster|            50.0|            54.0|      16.0|     174.0|2001-03-31|
# |   Pittsburgh|           102.0|           109.0|      23.0|     172.0|2001-03-31|
# |      Reading|            58.0|           125.0|      16.0|     177.0|2001-03-31|
# |         York|           117.0|            66.0|      18.0|     145.0|2001-03-31|
# |       Boston|            72.0|            62.0|      35.0|     145.0|2001-04-01|
# |       Newark|           101.0|           141.0|      34.0|      67.0|2001-08-16|
# |      Oakland|            60.0|            11.0|      36.0|      29.0|2001-12-05|
# |  Baton Rouge|            71.0|           109.0|      55.0|     169.0|2002-01-01|
# |       Boston|            78.0|            56.0|      31.0|     142.0|2002-01-01|
# |      Burbank|           131.0|            19.0|      51.0|     150.0|2002-01-01|
# |  Chula Vista|            93.0|            61.0|      30.0|      93.0|2002-01-01|
# |      Concord|            61.0|            41.0|      26.0|     135.0|2002-01-01|
# |   Costa Mesa|           102.0|            39.0|      49.0|      84.0|2002-01-01|
# |      El Paso|           111.0|            47.0|      42.0|     164.0|2002-01-01|
# |  Kansas City|            68.0|            66.0|      32.0|     127.0|2002-01-01|
# |   Long Beach|           106.0|            43.0|      52.0|      64.0|2002-01-01|
# |  Los Angeles|           112.0|            23.0|      61.0|     109.0|2002-01-01|
# |     New York|           102.0|           176.0|      33.0|     174.0|2002-01-01|
# |       Newark|           101.0|           105.0|      36.0|     161.0|2002-01-01|
# |      Oakland|            79.0|            29.0|      57.0|      47.0|2002-01-01|
# | Philadelphia|            85.0|            85.0|      39.0|     122.0|2002-01-01|
# |      Phoenix|            86.0|            30.0|      50.0|     122.0|2002-01-01|
# |    San Diego|           106.0|            40.0|      53.0|     129.0|2002-01-01|
# |San Francisco|            73.0|            72.0|      30.0|      42.0|2002-01-01|
# |    San Pablo|            51.0|            21.0|      20.0|      45.0|2002-01-01|
# |   Scottsdale|            64.0|            19.0|      34.0|      67.0|2002-01-01|
# |       Tucson|            61.0|            39.0|      23.0|     124.0|2002-01-01|
# |      Vallejo|            48.0|            24.0|      44.0|      87.0|2002-01-01|
# |   Washington|           101.0|            96.0|      55.0|     206.0|2002-01-01|
# |       Dallas|            77.0|            27.0|      30.0|     202.0|2002-01-10|
# |   Louisville|            40.0|           120.0|      19.0|     151.0|2002-02-28|
# |        Miami|            38.0|            21.0|       6.0|     109.0|2002-02-28|
# |      Bristol|            54.0|            80.0|      10.0|     204.0|2002-03-31|
# |    Charleroi|            55.0|           105.0|       8.0|     182.0|2002-03-31|
# |    Charlotte|            68.0|            92.0|      18.0|     182.0|2002-03-31|
# |      Detroit|           128.0|           115.0|      26.0|     156.0|2002-03-31|
# | Grand Rapids|            97.0|           105.0|      18.0|     154.0|2002-03-31|
# +-------------+----------------+----------------+----------+----------+----------+
# only showing top 100 rows

# %%
temp_pollution_yearly=sqlContext.sql("SELECT Polls.City, City_Temp.Yearly_Avg_Temp , Max(Polls.Max_NO2_AQI) AS max_NO2 ,Max(Polls.Max_SO2_AQI) AS MAX_SO2,Polls.Max_CO_AQI AS MAX_CO,Polls.Max_O3_AQI as MAX_03, Polls.Year FROM Polls JOIN City_Temp ON YEAR(Polls.Year)==City_Temp.Years AND Polls.City==City_Temp.City Group by City_Temp.Years, Polls.City, Polls.Max_NO2_AQI, Polls.Max_SO2_AQI, Polls.Max_CO_AQI,Polls.Max_O3_AQI, Polls.Year,City_Temp.Yearly_Avg_Temp ORDER BY Polls.Year, Polls.City ")
temp_pollution_yearly.toPandas().to_csv("temperature_pollution_Rerun.csv")

# %%
temp_pollution_yearly.registerTempTable("Temperature_Pollution_Dataset")
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py:329: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)

# %%
sqlContext.sql("SELECT * FROM Temperature_Pollution_Dataset ORDER BY Year(Year),max_NO2,MAX_SO2,MAX_CO,MAX_03  ").show(40)
# Out:
# +-------------+------------------+-------+-------+------+------+----------+
# |         City|   Yearly_Avg_Temp|max_NO2|MAX_SO2|MAX_CO|MAX_03|      Year|
# +-------------+------------------+-------+-------+------+------+----------+
# |    Charleroi|            11.368|   43.0|  110.0|  11.0| 169.0|2000-03-31|
# |    Lancaster|16.643333333333334|   55.0|   79.0|  19.0| 177.0|2000-03-31|
# |      Reading|11.226416666666667|   57.0|  135.0|  22.0| 172.0|2000-03-31|
# |   Louisville|13.499749999999999|   58.0|  128.0|  20.0| 129.0|2000-03-21|
# |      Vallejo|15.022000000000004|   62.0|   24.0|  57.0|  47.0|2000-01-01|
# |         York| 9.526916666666667|   63.0|  104.0|  22.0| 177.0|2000-03-31|
# |    San Pablo|26.966749999999994|   64.0|   39.0|  22.0|  74.0|2000-01-01|
# |      Bristol| 9.970083333333335|   64.0|   82.0|  19.0| 207.0|2000-03-31|
# |  Chula Vista|16.900083333333335|   70.0|   62.0|  35.0| 104.0|2000-01-01|
# |    Henderson|            18.509|   71.0|  136.0|  17.0| 122.0|2000-02-29|
# |San Francisco|15.022000000000004|   72.0|   27.0|  36.0|  36.0|2000-01-01|
# |      Concord|15.022000000000004|   72.0|   29.0|  31.0| 147.0|2000-01-01|
# |       Tucson|          18.66575|   73.0|   27.0|  31.0| 109.0|2000-01-01|
# |    Charlotte|16.428583333333332|   74.0|   92.0|  42.0| 205.0|2000-03-31|
# |  Kansas City|12.726750000000003|   74.0|  101.0|  57.0| 132.0|2000-01-01|
# |   Alexandria|         16.511125|   74.0|  109.0|  25.0| 150.0|2000-03-31|
# |   Pittsburgh|10.225166666666665|   74.0|  117.0|  18.0| 169.0|2000-03-31|
# |  Bakersfield|16.504083333333337|   88.0|   17.0|  43.0|  40.0|2000-11-01|
# |      Detroit| 9.344166666666666|   93.0|  134.0|  51.0| 114.0|2000-03-31|
# |  Baton Rouge|21.092500000000005|   94.0|   99.0|  48.0| 187.0|2000-01-01|
# | Philadelphia|12.311666666666667|   95.0|   89.0|  51.0| 140.0|2000-01-01|
# |       Dallas| 18.89666666666667|   97.0|   19.0|  25.0| 177.0|2000-01-01|
# |      Chicago|11.089666666666666|   97.0|  102.0|  26.0|  42.0|2000-01-06|
# |      El Paso| 16.88958333333333|   99.0|   50.0|  49.0| 154.0|2000-01-06|
# |     New York| 9.969083333333334|  101.0|  105.0|  55.0| 201.0|2000-05-05|
# |      Houston|21.342000000000002|  101.0|  172.0|  42.0| 203.0|2000-01-01|
# |   Costa Mesa|16.900083333333335|  102.0|   29.0|  69.0| 127.0|2000-01-01|
# |    San Diego|16.900083333333335|  104.0|   79.0|  65.0| 109.0|2000-01-01|
# |      Phoenix|22.003250000000005|  105.0|   41.0|  59.0| 132.0|2000-01-01|
# |   Long Beach|16.900083333333335|  108.0|   65.0|  63.0| 114.0|2000-01-01|
# |   Washington|12.277750000000003|  109.0|  104.0|  58.0| 164.0|2000-01-01|
# |  Los Angeles|14.816250000000004|  111.0|  100.0|  66.0| 169.0|2000-03-01|
# |      Burbank|16.643333333333334|  113.0|   14.0|  68.0| 202.0|2000-01-01|
# |   Scottsdale|22.003250000000005|  132.0|   31.0|  38.0| 106.0|2000-01-01|
# |    Charleroi|10.938249999999998|   42.0|  122.0|   5.0| 137.0|2001-03-31|
# |        Miami| 23.70183333333333|   44.0|   70.0|   3.0| 127.0|2001-01-01|
# |    Lancaster|          16.46625|   50.0|   54.0|  16.0| 174.0|2001-03-31|
# |      Vallejo| 15.24691666666667|   54.0|   23.0|  47.0|  80.0|2001-01-01|
# |       Tucson|18.269916666666663|   57.0|   14.0|  22.0| 100.0|2001-01-01|
# |   Louisville|14.103999999999997|   57.0|  137.0|  18.0| 127.0|2001-02-28|
# +-------------+------------------+-------+-------+------+------+----------+
# only showing top 40 rows

# %%
temperature_table=sqlContext.sql("SELECT * FROM Temperature_Pollution_Dataset ORDER BY Year(Year),max_NO2,MAX_SO2,MAX_CO,MAX_03  ")
temperature_table.toPandas().to_csv("Temperature_Values.csv")

# %%
table11 = sqlContext.sql("SELECT Yearly_Avg_Temp,max_NO2, MAX_SO2, MAX_CO,MAX_03 FROM Temperature_Pollution_Dataset")
table11.registerTempTable("Model_Dataset")
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py:329: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)

# %%
table11.toPandas().to_csv("Model_Data.csv")

# %%
dataFrame=sc.textFile("Model_Data.csv")
header = dataFrame.first()
dataFrame = dataFrame.filter(lambda x: x!=header)

# %%
type(dataFrame)
# Out:
# pyspark.rdd.PipelinedRDD

# %%
dataFrame = sc.parallelize(dataFrame.collect())
type(dataFrame)
# Out:
# pyspark.rdd.RDD

# %%
dataFrame=dataFrame.map(lambda line: line.split(','))
dataFrame
# Out:
# PythonRDD[431] at RDD at PythonRDD.scala:53

# %%
dataFrame.take(10)
# Out:
# [['0', '21.092500000000005', '94.0', '99.0', '48.0', '187.0'],
#  ['1', '16.643333333333334', '113.0', '14.0', '68.0', '202.0'],
#  ['2', '16.900083333333335', '70.0', '62.0', '35.0', '104.0'],
#  ['3', '15.022000000000004', '72.0', '29.0', '31.0', '147.0'],
#  ['4', '16.900083333333335', '102.0', '29.0', '69.0', '127.0'],
#  ['5', '18.89666666666667', '97.0', '19.0', '25.0', '177.0'],
#  ['6', '21.342000000000002', '101.0', '172.0', '42.0', '203.0'],
#  ['7', '12.726750000000003', '74.0', '101.0', '57.0', '132.0'],
#  ['8', '16.900083333333335', '108.0', '65.0', '63.0', '114.0'],
#  ['9', '12.311666666666667', '95.0', '89.0', '51.0', '140.0']]

# %%
from pyspark.mllib.tree import DecisionTree, DecisionTreeModel
from pyspark.mllib.util import MLUtils
from pyspark.mllib.regression import LabeledPoint


(trainingData, testData) = dataFrame.randomSplit([0.7, 0.3])
def parsePoint(line):
    values=[x for x in line]
    return LabeledPoint(values[1], values[2:])


TrainParseData = trainingData.map(parsePoint)
TestParseData=testData.map(parsePoint)

# Train a DecisionTree model.
#  Empty categoricalFeaturesInfo indicates all features are continuous.
model = DecisionTree.trainRegressor(TrainParseData, categoricalFeaturesInfo={},impurity='variance', maxDepth=5, maxBins=32)

# Evaluate model on test instances and compute test error
predictions = model.predict(TestParseData.map(lambda x: x.features))
labelsAndPredictions = TestParseData.map(lambda lp: lp.label).zip(predictions)
testMSE = labelsAndPredictions.map(lambda lp: (lp[0] - lp[1]) * (lp[0] - lp[1])).sum()/float(TestParseData.count())
print('Test Mean Squared Error = ' + str(testMSE))
print('Learned regression tree model:')
print(model.toDebugString())
# Out:
# Test Mean Squared Error = 15.863013292036312
# Learned regression tree model:
# DecisionTreeModel regressor of depth 5 with 59 nodes
#   If (feature 1 <= 33.5)
#    If (feature 1 <= 10.5)
#     If (feature 3 <= 95.0)
#      If (feature 0 <= 38.5)
#       Predict: 21.556083333333333
#      Else (feature 0 > 38.5)
#       If (feature 1 <= 6.5)
#        Predict: 10.904688271604938
#       Else (feature 1 > 6.5)
#        Predict: 13.665425925925925
#     Else (feature 3 > 95.0)
#      If (feature 3 <= 133.5)
#       If (feature 2 <= 9.5)
#        Predict: 19.712
#       Else (feature 2 > 9.5)
#        Predict: 15.587447916666667
#      Else (feature 3 > 133.5)
#       If (feature 3 <= 144.0)
#        Predict: 17.32675925925926
#       Else (feature 3 > 144.0)
#        Predict: 18.622722222222226
#    Else (feature 1 > 10.5)
#     If (feature 2 <= 21.0)
#      If (feature 3 <= 110.0)
#       If (feature 2 <= 19.5)
#        Predict: 20.04867992424242
#       Else (feature 2 > 19.5)
#        Predict: 27.018972222222203
#      Else (feature 3 > 110.0)
#       If (feature 2 <= 10.5)
#        Predict: 20.80617261904762
#       Else (feature 2 > 10.5)
#        Predict: 14.955927777777779
#     Else (feature 2 > 21.0)
#      If (feature 0 <= 46.5)
#       If (feature 1 <= 15.0)
#        Predict: 15.01975
#       Else (feature 1 > 15.0)
#        Predict: 9.616875
#      Else (feature 0 > 46.5)
#       If (feature 2 <= 23.5)
#        Predict: 15.494181481481483
#       Else (feature 2 > 23.5)
#        Predict: 17.586402777777774
#   Else (feature 1 > 33.5)
#    If (feature 2 <= 18.5)
#     If (feature 3 <= 50.5)
#      If (feature 1 <= 38.0)
#       Predict: 27.070916666666665
#      Else (feature 1 > 38.0)
#       If (feature 2 <= 16.5)
#        Predict: 14.3668720043573
#       Else (feature 2 > 16.5)
#        Predict: 16.97116666666666
#     Else (feature 3 > 50.5)
#      If (feature 0 <= 71.5)
#       If (feature 0 <= 69.5)
#        Predict: 12.61060320881226
#       Else (feature 0 > 69.5)
#        Predict: 16.551979166666655
#      Else (feature 0 > 71.5)
#       If (feature 3 <= 130.5)
#        Predict: 11.195225308641973
#       Else (feature 3 > 130.5)
#        Predict: 9.982142857142856
#    Else (feature 2 > 18.5)
#     If (feature 0 <= 60.5)
#      If (feature 1 <= 68.0)
#       If (feature 1 <= 50.5)
#        Predict: 12.463319444444444
#       Else (feature 1 > 50.5)
#        Predict: 10.278506944444443
#      Else (feature 1 > 68.0)
#       If (feature 1 <= 110.5)
#        Predict: 16.348041666666663
#       Else (feature 1 > 110.5)
#        Predict: 10.242374999999996
#     Else (feature 0 > 60.5)
#      If (feature 2 <= 60.5)
#       If (feature 3 <= 191.0)
#        Predict: 14.72489810090703
#       Else (feature 3 > 191.0)
#        Predict: 17.1408712121212
#      Else (feature 2 > 60.5)
#       If (feature 1 <= 101.5)
#        Predict: 17.0742
#       Else (feature 1 > 101.5)
#        Predict: 20.9345

# %%
test_table=sqlContext.sql("SELECT  Max_NO2_AQI,Max_SO2_AQI,Max_CO_AQI, Max_O3_AQI from Polls where YEAR(Year)>2013")
test_table.toPandas().to_csv("test_data.csv")

# %%
all=sqlContext.sql("SELECT  Year,City,Max_NO2_AQI,Max_SO2_AQI,Max_CO_AQI, Max_O3_AQI from Polls where YEAR(Year)>2013").show(10)
# Out:
# +----------+-------------+-----------+-----------+----------+----------+
# |      Year|         City|Max_NO2_AQI|Max_SO2_AQI|Max_CO_AQI|Max_O3_AQI|
# +----------+-------------+-----------+-----------+----------+----------+
# |2014-01-01|  Albuquerque|       43.0|       92.0|      15.0|      87.0|
# |2014-01-01| Arden-Arcade|       41.0|        7.0|      19.0|     122.0|
# |2014-01-02|       Austin|       34.0|       10.0|       5.0|      97.0|
# |2014-01-01|  Baton Rouge|       55.0|       54.0|      47.0|     129.0|
# |2014-01-01|   Beltsville|       40.0|       20.0|      10.0|     101.0|
# |2014-01-01|Bethel Island|       31.0|       14.0|       8.0|     101.0|
# |2014-01-01|   Birmingham|       82.0|       97.0|      11.0|      90.0|
# |2014-05-02|       Blaine|       37.0|       11.0|       8.0|      93.0|
# |2014-01-01|       Boston|       60.0|       40.0|      13.0|      54.0|
# |2014-01-01|      Bristol|       50.0|       20.0|      16.0|      84.0|
# +----------+-------------+-----------+-----------+----------+----------+
# only showing top 10 rows

# %%
all_data=sqlContext.sql("SELECT  Year,City,Max_NO2_AQI,Max_SO2_AQI,Max_CO_AQI, Max_O3_AQI from Polls where YEAR(Year)>2013")
all_data=all_data.toPandas()

# %%
test_table.registerTempTable("Table")
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py:329: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)

# %%
Panda_temp_table=test_table.toPandas()

# %%
test_table.describe()
# Out:
# DataFrame[summary: string, Max_NO2_AQI: string, Max_SO2_AQI: string, Max_CO_AQI: string, Max_O3_AQI: string]

# %%
type(test_table)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
test_table1=test_table.collect()

# %%
test_table.collect()[0].Max_SO2_AQI
# Out:
# 92.0

# %%
len(test_table.collect())
# Out:
# 218

# %%
list_predict=[]
for i in range(len(test_table.collect())):
    list_new=[test_table.collect()[i].Max_NO2_AQI,test_table.collect()[i].Max_SO2_AQI,test_table.collect()[i].Max_CO_AQI,test_table.collect()[i].Max_O3_AQI]
    list_predict.append(model.predict(list_new))

print(list_predict)
# Out:
# [12.61060320881226, 15.587447916666667, 19.712, 10.278506944444443, 20.04867992424242, 20.04867992424242, 11.195225308641973, 20.04867992424242, 12.61060320881226, 20.04867992424242, 15.587447916666667, 17.586402777777774, 14.955927777777779, 12.61060320881226, 12.61060320881226, 20.04867992424242, 12.61060320881226, 12.61060320881226, 12.61060320881226, 20.80617261904762, 15.494181481481483, 15.587447916666667, 20.04867992424242, 14.955927777777779, 17.586402777777774, 10.904688271604938, 17.32675925925926, 20.04867992424242, 20.04867992424242, 12.61060320881226, 15.587447916666667, 17.586402777777774, 20.04867992424242, 12.61060320881226, 21.556083333333333, 14.72489810090703, 18.622722222222226, 18.622722222222226, 12.61060320881226, 12.61060320881226, 11.195225308641973, 12.61060320881226, 12.61060320881226, 11.195225308641973, 15.587447916666667, 17.586402777777774, 15.494181481481483, 12.61060320881226, 14.955927777777779, 14.955927777777779, 17.586402777777774, 20.04867992424242, 12.61060320881226, 15.494181481481483, 17.586402777777774, 19.712, 20.04867992424242, 17.586402777777774, 12.61060320881226, 14.955927777777779, 21.556083333333333, 20.04867992424242, 15.587447916666667, 21.556083333333333, 18.622722222222226, 14.955927777777779, 10.904688271604938, 20.04867992424242, 10.904688271604938, 20.04867992424242, 12.61060320881226, 20.80617261904762, 20.04867992424242, 17.586402777777774, 20.04867992424242, 18.622722222222226, 21.556083333333333, 20.04867992424242, 14.72489810090703, 14.72489810090703, 14.955927777777779, 14.955927777777779, 12.61060320881226, 15.587447916666667, 15.494181481481483, 14.72489810090703, 14.955927777777779, 20.04867992424242, 12.61060320881226, 15.587447916666667, 20.80617261904762, 17.586402777777774, 14.955927777777779, 12.61060320881226, 12.61060320881226, 14.955927777777779, 12.61060320881226, 12.61060320881226, 15.587447916666667, 9.982142857142856, 15.587447916666667, 18.622722222222226, 20.04867992424242, 14.955927777777779, 14.72489810090703, 10.904688271604938, 18.622722222222226, 14.955927777777779, 14.955927777777779, 12.61060320881226, 10.904688271604938, 17.586402777777774, 12.61060320881226, 12.463319444444444, 21.556083333333333, 14.72489810090703, 18.622722222222226, 14.955927777777779, 12.61060320881226, 21.556083333333333, 14.955927777777779, 12.61060320881226, 11.195225308641973, 12.61060320881226, 21.556083333333333, 14.72489810090703, 14.955927777777779, 14.955927777777779, 18.622722222222226, 14.955927777777779, 15.494181481481483, 12.61060320881226, 20.04867992424242, 14.72489810090703, 17.586402777777774, 21.556083333333333, 15.494181481481483, 15.494181481481483, 21.556083333333333, 20.04867992424242, 15.587447916666667, 21.556083333333333, 18.622722222222226, 14.955927777777779, 17.32675925925926, 20.04867992424242, 20.04867992424242, 19.712, 12.61060320881226, 21.556083333333333, 14.955927777777779, 15.587447916666667, 21.556083333333333, 17.1408712121212, 21.556083333333333, 20.80617261904762, 14.955927777777779, 15.494181481481483, 20.04867992424242, 21.556083333333333, 12.61060320881226, 21.556083333333333, 27.018972222222203, 13.665425925925925, 19.712, 10.278506944444443, 13.665425925925925, 15.587447916666667, 21.556083333333333, 19.712, 20.04867992424242, 12.61060320881226, 19.712, 10.904688271604938, 21.556083333333333, 21.556083333333333, 21.556083333333333, 27.018972222222203, 21.556083333333333, 13.665425925925925, 10.904688271604938, 12.61060320881226, 15.494181481481483, 20.04867992424242, 20.04867992424242, 21.556083333333333, 10.904688271604938, 20.04867992424242, 13.665425925925925, 20.04867992424242, 12.61060320881226, 20.04867992424242, 21.556083333333333, 20.04867992424242, 13.665425925925925, 21.556083333333333, 27.018972222222203, 20.04867992424242, 13.665425925925925, 20.04867992424242, 10.904688271604938, 13.665425925925925, 10.904688271604938, 10.904688271604938, 20.04867992424242, 10.904688271604938, 13.665425925925925, 10.9046882716049 ...

# %%
all_data['Temperature_Predicted']=list_predict

# %%
all_data
# Out:
#            Year          City  Max_NO2_AQI  Max_SO2_AQI  Max_CO_AQI  \
# 0    2014-01-01   Albuquerque         43.0         92.0        15.0
# 1    2014-01-01  Arden-Arcade         41.0          7.0        19.0
# 2    2014-01-02        Austin         34.0         10.0         5.0
# 3    2014-01-01   Baton Rouge         55.0         54.0        47.0
# 4    2014-01-01    Beltsville         40.0         20.0        10.0
# ..          ...           ...          ...          ...         ...
# 213  2016-03-04    Washington         55.0         11.0         9.0
# 214  2016-01-01         Welby         62.0         14.0        18.0
# 215  2016-01-01    Wilmington         58.0         13.0        16.0
# 216  2016-01-01   Winter Park         38.0          7.0        15.0
# 217  2016-01-01          York         56.0         26.0        11.0
#
#      Max_O3_AQI  Temperature_Predicted
# 0          87.0              12.610603
# 1         122.0              15.587448
# 2          97.0              19.712000
# 3         129.0              10.278507
# 4         101.0              20.048680
# ..          ...                    ...
# 213        93.0              20.048680
# 214        49.0              20.048680
# 215        61.0              20.048680
# 216        67.0              21.556083
# 217        64.0              20.048680
#
# [218 rows x 7 columns]

# %%
all_data.to_csv("Predicted_temperatures_DT.csv")

# %%
list_of_data=[]
for i in range(len(test_table.collect())):
    list_of_data.append([list_predict[i],test_table.collect()[i].Max_NO2_AQI,test_table.collect()[i].Max_SO2_AQI,test_table.collect()[i].Max_CO_AQI,test_table.collect()[i].Max_O3_AQI])

# %%
list_of_data
# Out:
# [[12.61060320881226, 43.0, 92.0, 15.0, 87.0],
#  [15.587447916666667, 41.0, 7.0, 19.0, 122.0],
#  [19.712, 34.0, 10.0, 5.0, 97.0],
#  [10.278506944444443, 55.0, 54.0, 47.0, 129.0],
#  [20.04867992424242, 40.0, 20.0, 10.0, 101.0],
#  [20.04867992424242, 31.0, 14.0, 8.0, 101.0],
#  [11.195225308641973, 82.0, 97.0, 11.0, 90.0],
#  [20.04867992424242, 37.0, 11.0, 8.0, 93.0],
#  [12.61060320881226, 60.0, 40.0, 13.0, 54.0],
#  [20.04867992424242, 50.0, 20.0, 16.0, 84.0],
#  [15.587447916666667, 71.0, 6.0, 34.0, 129.0],
#  [17.586402777777774, 93.0, 16.0, 43.0, 151.0],
#  [14.955927777777779, 62.0, 14.0, 17.0, 115.0],
#  [12.61060320881226, 12.0, 117.0, 5.0, 151.0],
#  [12.61060320881226, 42.0, 82.0, 9.0, 100.0],
#  [20.04867992424242, 48.0, 11.0, 17.0, 105.0],
#  [12.61060320881226, 47.0, 122.0, 9.0, 126.0],
#  [12.61060320881226, 64.0, 95.0, 15.0, 97.0],
#  [12.61060320881226, 45.0, 41.0, 13.0, 133.0],
#  [20.80617261904762, 37.0, 13.0, 7.0, 129.0],
#  [15.494181481481483, 57.0, 11.0, 22.0, 129.0],
#  [15.587447916666667, 54.0, 9.0, 17.0, 100.0],
#  [20.04867992424242, 42.0, 19.0, 8.0, 71.0],
#  [14.955927777777779, 39.0, 19.0, 13.0, 151.0],
#  [17.586402777777774, 108.0, 27.0, 25.0, 93.0],
#  [10.904688271604938, 44.0, 1.0, 9.0, 93.0],
#  [17.32675925925926, 33.0, 6.0, 7.0, 143.0],
#  [20.04867992424242, 41.0, 14.0, 14.0, 84.0],
#  [20.04867992424242, 40.0, 20.0, 15.0, 108.0],
#  [12.61060320881226, 49.0, 43.0, 16.0, 112.0],
#  [15.587447916666667, 54.0, 1.0, 20.0, 115.0],
#  [17.586402777777774, 68.0, 16.0, 32.0, 115.0],
#  [20.04867992424242, 44.0, 20.0, 11.0, 101.0],
#  [12.61060320881226, 51.0, 61.0, 16.0, 105.0],
#  [21.556083333333333, 33.0, 1.0, 10.0, 46.0],
#  [14.72489810090703, 95.0, 49.0, 22.0, 32.0],
#  [18.622722222222226, 68.0, 6.0, 15.0, 200.0],
#  [18.622722222222226, 56.0, 9.0, 27.0, 172.0],
#  [12.61060320881226, 24.0, 54.0, 3.0, 87.0],
#  [12.61060320881226, 22.0, 62.0, 7.0, 97.0],
#  [11.195225308641973, 72.0, 54.0, 17.0, 93.0],
#  [12.61060320881226, 54.0, 105.0, 14.0, 105.0],
#  [12.61060320881226, 42.0, 81.0, 15.0, 108.0],
#  [11.195225308641973, 77.0, 84.0, 13.0, 119.0],
#  [15.587447916666667, 33.0, 7.0, 18.0, 101.0],
#  [17.586402777777774, 107.0, 20.0, 30.0, 105.0],
#  [15.494181481481483, 86.0, 21.0, 23.0, 172.0],
#  [12.61060320881226, 45.0, 51.0, 10.0, 77.0],
#  [14.955927777777779, 62.0, 27.0, 16.0, 126.0],
#  [14.955927777777779, 68.0, 29.0, 17.0, 133.0],
#  [17.586402777777774, 82.0, 19.0, 28.0, 115.0],
#  [20.04867992424242, 54.0, 16.0, 14.0, 100.0],
#  [12.61060320881226, 54.0, 39.0, 9.0, 97.0],
#  [15.494181481481483, 68.0, 30.0, 23.0, 122.0],
#  [17.586402777777774, 53.0, 23.0, 30.0, 64.0],
#  [19.712, 44.0, 10.0, 8.0, 115.0],
#  [20.04867992424242, 65.0, 17.0, 15.0, 90.0],
#  [17.586402777777774, 68.0, 16.0, 28.0, 147.0],
#  [12.61060320881226, 39.0, 79.0, 17.0, 101.0],
#  [14.955927777777779, 41.0, 31.0, 15.0, 115.0],
#  [21.556083333333333, 25.0, 4.0, 5.0, 48.0],
#  [20.04867992424242, 40.0, 11.0, 14.0, 100.0],
#  [15.587447916666667, 57.0, 9.0, 19.0, 119.0],
#  [21.556083333333333, 22.0, 6.0, 0.0, 87.0],
#  [18.622722222222226, 56.0, 7.0, 22.0, 197.0],
#  [14.955927777777779, 55.0, 33.0, 19.0, 122.0],
#  [10.904688271604938, 55.0, 4.0, 22.0, 87.0],
#  [20.04867992424242, 48.0, 21.0, 11.0, 67.0],
#  [10.904688271604938, 42.0, 3.0, 5.0, 44.0],
#  [20.04867992424242, 37.0, 29.0, 6.0, 105.0],
#  [12.61060320881226, 50.0, 66.0, 16.0, 101.0],
#  [20.80617261904762, 39.0, 13.0, 9.0, 122.0],
#  [20.04867992424242, 43.0, 13.0, 11.0, 105.0],
#  [17.586402777777774, 47.0, 33.0, 24.0, 93.0],
#  [20.04867992424242, 36.0, 21.0, 6.0, 101.0],
#  [18.622722222222226, 64.0, 6.0, 13.0, 177.0],
#  [21.556083333333333, 26.0, 4.0, 8.0, 71.0],
#  [20.04867992424242, 29.0, 17.0, 6.0, 105.0],
#  [14.72489810090703, 62.0, 40.0, 25.0, 133.0],
#  [14.72489810090703, 102.0, 64.0, 20.0, 108.0],
#  [14.955927777777779, 52.0, 19.0, 13.0, 143.0],
#  [14.955927777777779, 40.0, 33.0, 19.0, 126.0],
#  [12.61060320881226, 55.0, 54.0, 7.0, 87.0],
#  [15.587447916666667, 45.0, 9.0, 16.0, 101.0],
#  [15.494181481481483, 49.0, 11.0, 23.0, 159.0],
#  [14.72489810090703, 66.0, 37.0, 19.0, 122.0],
#  [14.955927777777779, 42.0, 16.0, 11.0, 156.0],
#  [20.04867992424242, 26.0, 11.0, 10.0, 105.0],
#  [12.61060320881226, 45.0, 69.0, 9.0, 147.0],
#  [15.587447916666667, 85.0, 10.0, 14.0, 105.0],
#  [20.80617261904762, 57.0, 17.0, 10.0, 126.0],
#  [17.586402777777774, 82.0, 23.0, 45.0, 140.0],
#  [14.955927777777779, 64.0, 29.0, 19.0, 161.0],
#  [12.61060320881226, 10.0, 36.0, 3.0, 101.0],
#  [12.61060320881226, 48.0, 81.0, 14.0, 115.0],
#  [14.955927777777779, 42.0, 23.0, 16.0, 119.0],
#  [12.61060320881226, 54.0, 62.0, 9.0, 115.0],
#  [12.61060320881226, 55.0, 108.0, 15.0, 90.0],
#  [15.587447916666667, 31.0, 9.0, 15.0, 108.0],
#  [9.982142857142856, 106.0, 49.0, 15.0, 147.0],
#  [15.587447916666667, 49.0, 6.0, 25.0, 129.0],
#  [18.622722222222226, 54.0, 7.0, 19.0, 147.0],
#  [20.04867992424242, 47.0, 14.0, 11.0, 90.0],
#  [14.955927777777779, 64.0, 23.0, 13.0, 174.0],
#  [14.72489810090703, 94.0, 34.0, 27.0, 122.0],
#  [10.904688271604938, 39.0, 3.0, 8.0, 84.0],
#  [18.622722222222226, 54.0, 1.0, 6.0, 147.0],
#  [14.955927777777779, 39.0, 14.0, 13.0, 119.0],
#  [14.955927777777779, 46.0, 23.0, 13.0, 159.0],
#  [12.61060320881226, 44.0, 41.0, 14.0, 115.0],
#  [10.904688271604938, 56.0, 1.0, 13.0, 90.0],
#  [17.586402777777774, 93.0, 17.0, 27.0, 115.0],
#  [12.61060320881226, 50.0, 54.0, 10.0, 115.0],
#  [12.463319444444444, 50.0, 43.0, 19.0, 115.0],
#  [21.556083333333333, 24.0, 1.0, 10.0, 42.0],
#  [14.72489810090703, 83.0, 72.0, 43.0, 47.0],
#  [18.622722222222226, 88.0, 6.0, 14.0, 206.0],
#  [14.955927777777779, 46.0, 14.0, 20.0, 182.0],
#  [12.61060320881226, 15.0, 46.0, 5.0, 100.0],
#  [21.556083333333333, 21.0, 7.0, 7.0, 90.0],
#  [14.955927777777779, 87.0, 14.0, 14.0, 169.0],
#  [12.61060320881226, 56.0, 102.0, 17.0, 101.0],
#  [11.195225308641973, 85.0, 85.0, 13.0, 97.0],
#  [12.61060320881226, 55.0, 74.0, 14.0, 87.0],
#  [21.556083333333333, 26.0, 3.0, 9.0, 67.0],
#  [14.72489810090703, 72.0, 52.0, 25.0, 87.0],
#  [14.955927777777779, 86.0, 20.0, 20.0, 122.0],
#  [14.955927777777779, 42.0, 21.0, 11.0, 174.0],
#  [18.622722222222226, 79.0, 10.0, 15.0, 169.0],
#  [14.955927777777779, 97.0, 19.0, 18.0, 136.0],
#  [15.494181481481483, 77.0, 11.0, 23.0, 112.0],
#  [12.61060320881226, 54.0, 41.0, 11.0, 97.0],
#  [20.04867992424242, 41.0, 21.0, 9.0, 101.0],
#  [14.72489810090703, 65.0, 92.0, 27.0, 150.0],
#  [17.586402777777774, 54.0, 30.0, 30.0, 80.0],
#  [21.556083333333333, 37.0, 4.0, 23.0, 64.0],
#  [15.494181481481483, 61.0, 13.0, 23.0, 122.0],
#  [15.494181481481483, 83.0, 23.0, 23.0, 74.0],
#  [21.556083333333333, 26.0, 9.0, 6.0, 51.0],
#  [20.04867992424242, 38.0, 13.0, 15.0, 101.0],
#  [15.587447916666667, 51.0, 10.0, 17.0, 115.0],
#  [21.556083333333333, 17.0, 9.0, 0.0, 71.0],
#  [18.622722222222226, 54.0, 1.0, 19.0, 200.0],
#  [14.955927777777779, 61.0, 33.0, 20.0, 143.0],
#  [17.32675925925926, 46.0, 4.0, 18.0, 136.0],
#  [20.04867992424242, 42.0, 14.0, 13.0, 74.0],
#  [20.04867992424242, 52.0, 13.0, 9.0, 46.0],
#  [19.712, 36.0, 6.0, 8.0, 122.0],
#  [12.61060320881226, 55.0, 57.0, 17.0, 64.0],
#  [21.556083333333333, 38.0, 7.0, 9.0, 80.0],
#  [14.955927777777779, 48.0, 19.0, 14.0, 147.0],
#  [15.587447916666667, 42.0, 7.0, 22.0, 100.0],
#  [21.556083333333333, 8.0, 4.0, 5.0, 71.0],
#  [17.1408712121212, 104.0, 147.0, 57.0, 200.0],
#  [21.556083333333333, 31.0, 7.0, 6.0, 90.0],
#  [20.80617261904762, 32.0, 14.0, 3.0, 115.0],
#  [14.955927777777779, 60.0, 26.0, 17.0, 126.0],
#  [15.494181481481483, 70.0, 27.0, 23.0, 115.0],
#  [20.04867992424242, 41.0, 14.0, 14.0, 105.0],
#  [21.556083333333333, 33.0, 7.0, 15.0, 84.0],
#  [12.61060320881226, 64.0, 56.0, 11.0, 108.0],
#  [21.556083333333333, 31.0, 6.0, 16.0, 32.0],
#  [27.018972222222203, 80.0, 29.0, 20.0, 77.0],
#  [13.665425925925925, 44.0, 10.0, 9.0, 71.0],
#  [19.712, 25.0, 4.0, 7.0, 97.0],
#  [10.278506944444443, 48.0, 65.0, 20.0, 112.0],
#  [13.665425925925925, 48.0, 9.0, 14.0, 45.0],
#  [15.587447916666667, 83.0, 9.0, 35.0, 97.0],
#  [21.556083333333333, 14.0, 3.0, 3.0, 74.0],
#  [19.712, 39.0, 6.0, 9.0, 100.0],
#  [20.04867992424242, 46.0, 14.0, 9.0, 84.0],
#  [12.61060320881226, 61.0, 55.0, 11.0, 54.0],
#  [19.712, 27.0, 4.0, 8.0, 97.0],
#  [10.904688271604938, 74.0, 4.0, 9.0, 54.0],
#  [21.556083333333333, 33.0, 4.0, 6.0, 84.0],
#  [21.556083333333333, 37.0, 10.0, 14.0, 74.0],
#  [21.556083333333333, 37.0, 4.0, 7.0, 47.0],
#  [27.018972222222203, 85.0, 11.0, 20.0, 46.0],
#  [21.556083333333333, 32.0, 0.0, 6.0, 80.0],
#  [13.665425925925925, 42.0, 7.0, 11.0, 44.0],
#  [10.904688271604938, 45.0, 6.0, 10.0, 80.0],
#  [12.61060320881226, 37.0, 40.0, 11.0, 67.0],
#  [15.494181481481483, 77.0, 21.0, 23.0, 64.0],
#  [20.04867992424242, 34.0, 11.0, 7.0, 50.0],
#  [20.04867992424242, 48.0, 20.0, 17.0, 74.0],
#  [21.556083333333333, 22.0, 1.0, 10.0, 38.0],
#  [10.904688271604938, 50.0, 0.0, 19.0, 50.0],
#  [20.04867992424242, 22.0, 11.0, 3.0, 61.0],
#  [13.665425925925925, 54.0, 9.0, 15.0, 61.0],
#  [20.04867992424242, 54.0, 13.0, 16.0, 105.0],
#  [12.61060320881226, 42.0, 81.0, 8.0, 64.0],
#  [20.04867992424242, 42.0, 19.0, 7.0, 49.0],
#  [21.556083333333333, 28.0, 1.0, 5.0, 48.0],
#  [20.04867992424242, 88.0, 14.0, 14.0, 61.0],
#  [13.665425925925925, 41.0, 7.0, 10.0, 46.0],
#  [21.556083333333333, 37.0, 7.0, 7.0, 44.0],
#  [27.018972222222203, 65.0, 21.0, 20.0, 74.0],
#  [20.04867992424242, 45.0, 30.0, 16.0, 45.0],
#  [13.665425925925925, 63.0, 9.0, 18.0, 67.0],
#  [20.04867992424242, 44.0, 17.0, 15.0, 51.0],
#  [10.904688271604938, 42.0, 6.0, 10.0, 54.0],
#  [13.665425925925925, 45.0, 7.0, 13.0, 47.0],
#  [10.904688271604938, 57.0, 4.0, 15.0, 36.0],
#  [10.904688271604938, 48.0, 1.0, 15.0, 67.0],
#  [20.04867992424242, 36.0, 17.0, 11.0, 61.0],
#  [10.904688271604938, 41.0, 3.0, 8.0, 35.0],
#  [13.665425925925925, 40.0, 7.0, 11.0, 43.0],
#  [10.904688271604938, 42.0, 1.0, 8.0, 58.0],
#  [20.04867992424242, 42.0, 13.0, 14.0, 74.0],
#  [21.556083333333333, 36.0, 9.0, 20.0, 84.0],
#  [21.556083333333333, 7.0, 4.0, 5.0, 51.0],
#  [10.904688271604938, 51.0, 3.0, 10.0, 84.0],
#  [20.04867992424242, 41.0, 13.0, 3.0, 64.0],
#  [20.04867992424242, 55.0, 11.0, 9.0, 93.0],
#  [20.04867992424242, 62.0, 14.0, 18.0, 49.0],
#  [20.04867992424242, 58.0, 13.0, 16.0, 61.0],
#  [21.556083333333333, 38.0, 7.0, 15.0, 67.0],
#  [20.04867992424242, 56.0, 26.0, 11.0, 64.0]]

# %%
list_target=[]
list_features=[]
for i in range(len(list_of_data)-200):
    list_target.append(list_of_data[i][0])
    list_features.append(list_of_data[i][1:])
len(list_target)
# Out:
# 18

# %%
list_target[0]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=[30,30])

y_values = [x for x in list_target]
x_values = [x for x in list_features]
plt.xlabel("AQI Values",fontsize=30)
plt.ylabel("Temperature",fontsize=30)
plt.plot(x_values,y_values)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=[12, 8])  # Adjust figure size as needed

y_values = [x for x in list_target]
x_values = [x for x in list_features]

plt.plot(x_values, y_values, marker='o', linestyle='-', color='b', markersize=8)  # Customize marker, linestyle, and color
plt.xlabel("AQI Values", fontsize=12)  # Adjust fontsize as needed
plt.ylabel("Temperature", fontsize=12)  # Adjust fontsize as needed
plt.title("AQI Values vs Temperature", fontsize=14)  # Add title and adjust fontsize as needed
plt.grid(True)  # Add grid

plt.tick_params(axis='both', which='major', labelsize=10)  # Adjust tick label size as needed
plt.xticks(rotation=45)  # Rotate x-axis labels if necessary

plt.tight_layout()  # Adjust layout

plt.show()

# %%
import plotly.express as px

# Assuming list_target and list_features are your data lists

fig = px.scatter(x=list_features, y=list_target, labels={'x':'AQI Values', 'y':'Temperature'},
                 title='Scatter Plot of AQI Values vs Temperature')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-cd704b8d16e7> in <cell line: 5>()
#       3 # Assuming list_target and list_features are your data lists
#       4
# ----> 5 fig = px.scatter(x=list_features, y=list_target, labels={'x':'AQI Values', 'y':'Temperature'},
#       6                  title='Scatter Plot of AQI Values vs Temperature')
#       7 fig.show()
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#      67
#      68
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2001     apply_default_cascade(args)
#    2002
# -> 2003     args = build_dataframe(args, constructor)
#    2004     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2005         args = process_dataframe_hierarchy(args)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1410     # now that things have been prepped, we do the systematic rewriting of `args`
#    1411
# -> 1412     df_output, wide_id_vars = process_args_into_dataframe(
#    1413         args, wide_mode, var_name, value_name
#    1414     )
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1244
#    1245                 if length and len(argument) != length:
# -> 1246                     raise ValueError(
#    1247                         "All arguments should have the same length. "
#    1248                         "The length of argument `%s` is %d, whereas the "
#
# ValueError: All arguments should have the same length. The length of argument `wide_variable_0` is 4, whereas the length of  previously-processed arguments ['y'] is 18

# %%
print(len(list_features))
print(len(list_target))
# Out:
# 18
# 18

# %%
import plotly.graph_objects as go

# Assuming list_target and list_features are your data lists

fig = go.Figure(data=go.Scatter(x=list_features, y=list_target, mode='markers'))
fig.update_layout(
    title='Scatter Plot of AQI Values vs Temperature',
    xaxis_title='AQI Values',
    yaxis_title='Temperature'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5593af83-1d82-43e9-b3fc-1674cd14bd6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5593af83-1d82-43e9-b3fc-1674cd14bd6b")) {                    Plotly.newPlot(                        "5593af83-1d82-43e9-b3fc-1674cd14bd6b",                        [{"mode":"markers","x":[[43.0,92.0,15.0,87.0],[41.0,7.0,19.0,122.0],[34.0,10.0,5.0,97.0],[55.0,54.0,47.0,129.0],[40.0,20.0,10.0,101.0],[31.0,14.0,8.0,101.0],[82.0,97.0,11.0,90.0],[37.0,11.0,8.0,93.0],[60.0,40.0,13.0,54.0],[50.0,20.0,16.0,84.0],[71.0,6.0,34.0,129.0],[93.0,16.0,43.0,151.0],[62.0,14.0,17.0,115.0],[12.0,117.0,5.0,151.0],[42.0,82.0,9.0,100.0],[48.0,11.0,17.0,105.0],[47.0,122.0,9.0,126.0],[64.0,95.0,15.0,97.0]],"y":[12.61060320881226,15.587447916666667,19.712,10.278506944444443,20.04867992424242,20.04867992424242,11.195225308641973,20.04867992424242,12.61060320881226,20.04867992424242,15.587447916666667,17.586402777777774,14.955927777777779,12.61060320881226,12.61060320881226,20.04867992424242,12.61060320881226,12.61060320881226],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outline ...

# %%
import plotly.graph_objects as go

# Assuming list_target and list_features are your data lists

fig = go.Figure(data=go.Scatter(x=list_features, y=list_target, mode='markers', marker=dict(size=8)))
fig.update_layout(
    title='Scatter Plot of AQI Values vs Temperature',
    xaxis_title='AQI Values',
    yaxis_title='Temperature',
    xaxis=dict(range=[min(list_features), max(list_features)]),  # Set x-axis range
    yaxis=dict(range=[min(list_target), max(list_target)]),  # Set y-axis range
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="48caded8-0f50-4a7a-b0f2-3264750df6ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48caded8-0f50-4a7a-b0f2-3264750df6ed")) {                    Plotly.newPlot(                        "48caded8-0f50-4a7a-b0f2-3264750df6ed",                        [{"marker":{"size":8},"mode":"markers","x":[[43.0,92.0,15.0,87.0],[41.0,7.0,19.0,122.0],[34.0,10.0,5.0,97.0],[55.0,54.0,47.0,129.0],[40.0,20.0,10.0,101.0],[31.0,14.0,8.0,101.0],[82.0,97.0,11.0,90.0],[37.0,11.0,8.0,93.0],[60.0,40.0,13.0,54.0],[50.0,20.0,16.0,84.0],[71.0,6.0,34.0,129.0],[93.0,16.0,43.0,151.0],[62.0,14.0,17.0,115.0],[12.0,117.0,5.0,151.0],[42.0,82.0,9.0,100.0],[48.0,11.0,17.0,105.0],[47.0,122.0,9.0,126.0],[64.0,95.0,15.0,97.0]],"y":[12.61060320881226,15.587447916666667,19.712,10.278506944444443,20.04867992424242,20.04867992424242,11.195225308641973,20.04867992424242,12.61060320881226,20.04867992424242,15.587447916666667,17.586402777777774,14.955927777777779,12.61060320881226,12.61060320881226,20.04867992424242,12.61060320881226,12.61060320881226],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{ ...

# %%
import plotly.graph_objects as go

# Assuming list_target and list_features are your data lists

fig = go.Figure(data=go.Scatter(x=list_features, y=list_target, mode='markers', marker=dict(size=8)))
fig.update_layout(
    title='Scatter Plot of AQI Values vs Temperature',
    xaxis_title='AQI Values',
    yaxis_title='Temperature',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9d7e08dc-8b18-4c66-8fbe-4b7a8f994f5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d7e08dc-8b18-4c66-8fbe-4b7a8f994f5d")) {                    Plotly.newPlot(                        "9d7e08dc-8b18-4c66-8fbe-4b7a8f994f5d",                        [{"marker":{"size":8},"mode":"markers","x":[[43.0,92.0,15.0,87.0],[41.0,7.0,19.0,122.0],[34.0,10.0,5.0,97.0],[55.0,54.0,47.0,129.0],[40.0,20.0,10.0,101.0],[31.0,14.0,8.0,101.0],[82.0,97.0,11.0,90.0],[37.0,11.0,8.0,93.0],[60.0,40.0,13.0,54.0],[50.0,20.0,16.0,84.0],[71.0,6.0,34.0,129.0],[93.0,16.0,43.0,151.0],[62.0,14.0,17.0,115.0],[12.0,117.0,5.0,151.0],[42.0,82.0,9.0,100.0],[48.0,11.0,17.0,105.0],[47.0,122.0,9.0,126.0],[64.0,95.0,15.0,97.0]],"y":[12.61060320881226,15.587447916666667,19.712,10.278506944444443,20.04867992424242,20.04867992424242,11.195225308641973,20.04867992424242,12.61060320881226,20.04867992424242,15.587447916666667,17.586402777777774,14.955927777777779,12.61060320881226,12.61060320881226,20.04867992424242,12.61060320881226,12.61060320881226],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{ ...

# %%
import plotly.graph_objects as go

# Assuming list_target and list_features are your data lists

fig = go.Figure(data=go.Scatter(x=list_features, y=list_target, mode='markers', marker=dict(size=8)))
fig.update_layout(
    title='Scatter Plot of AQI Values vs Temperature',
    xaxis_title='AQI Values',
    yaxis_title='Temperature',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="31da9fbd-ff53-4c8e-a1ec-4a5ebb3df486" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31da9fbd-ff53-4c8e-a1ec-4a5ebb3df486")) {                    Plotly.newPlot(                        "31da9fbd-ff53-4c8e-a1ec-4a5ebb3df486",                        [{"marker":{"size":8},"mode":"markers","x":[[43.0,92.0,15.0,87.0],[41.0,7.0,19.0,122.0],[34.0,10.0,5.0,97.0],[55.0,54.0,47.0,129.0],[40.0,20.0,10.0,101.0],[31.0,14.0,8.0,101.0],[82.0,97.0,11.0,90.0],[37.0,11.0,8.0,93.0],[60.0,40.0,13.0,54.0],[50.0,20.0,16.0,84.0],[71.0,6.0,34.0,129.0],[93.0,16.0,43.0,151.0],[62.0,14.0,17.0,115.0],[12.0,117.0,5.0,151.0],[42.0,82.0,9.0,100.0],[48.0,11.0,17.0,105.0],[47.0,122.0,9.0,126.0],[64.0,95.0,15.0,97.0]],"y":[12.61060320881226,15.587447916666667,19.712,10.278506944444443,20.04867992424242,20.04867992424242,11.195225308641973,20.04867992424242,12.61060320881226,20.04867992424242,15.587447916666667,17.586402777777774,14.955927777777779,12.61060320881226,12.61060320881226,20.04867992424242,12.61060320881226,12.61060320881226],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{ ...

# %%
import pandas as pd
import numpy as np
causes_of_death=pd.read_csv("/content/drive/MyDrive/NCHS_-_Leading_Causes_of_Death__United_States.csv")

# %%
not_wanted_diseases_list=[
                          'All Causes',
                          'Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)',
                          'Assault (homicide) by discharge of firearms (*U01.4,X93-X95)',
                          'Assault (homicide) by other and unspecified means and their sequelae (*U01.0-*U01.3,*U01.5-*U01.9,*U02,X85-X92,X96-Y09,Y87.1)'
                          'Legal intervention (Y35,Y89.0)',
                          'Events of undetermined intent (Y10-Y34,Y87.2,Y89.9)',
                          'Discharge of firearms, undetermined intent (Y22-Y24)',
                          'Other and unspecified events of undetermined intent and their sequelae (Y10-Y21,Y25-Y34,Y87.2,Y89.9)',
                          'Operations of war and their sequelae (Y36,Y89.1)',
                          'Complications of medical and surgical care (Y40-Y84,Y88)',
                          'Other land transport accidents (V01,V05-V06,V09.1,V09.3-V09.9, V10-V11,V15-V18,V19.3,V19.8-V19.9,V80.0-V80.2,V80.6-V80.9,V81.2-V81.9,V82.2-V82.9,V87.9,V88.9,V89.1,V89.3,V89.9)',
                          'Water, air and space, and other and unspecified transport accidents and theirsequelae (V90-V99,Y85)',
                          'Nontransport accidents (W00-X59,Y86)',
                          'Falls (W00-W19)',
                          'Accidental discharge of firearms (W32-W34)',
                          'Accidental drowning and submersion (W65-W74)',
                          'Accidental exposure to smoke, fire and flames (X00-X09)',
                          'Accidental poisoning and exposure to noxious substances (X40-X49)',
                          'Other and unspecified nontransport accidents and their sequelae (W20-W31,W35-W64,W75-W99,X10-X39,X50-X59,Y86)',
                          'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
                          'Intentional self-harm (suicide) by discharge of firearms (X72-X74)',
                          'Intentional self-harm (suicide) by other and unspecified means and their sequelae (*U03,X60-X71,X75-X84,Y87.0)',
                          'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
                          'Transport accidents (V01-V99,Y85)',
                          'Motor vehicle accidents (V02-V04,V09.0,V09.2,V12-V14,V19.0-V19.2,V19.4-V19.6,V20-V79,V80.3-V80.5,V81.0-V81.1,V82.0-V82.1,V83-V86,V87.0-V87.8,V88.0-V88.8,V89.0,V89.2)',
                          'All other diseases (Residual) (D65-E07,E15-E34,E65-F99,G04-G14,G23-G25,G31-H93,K00-K22,K29-K31,K50-K66,K71-K72,K75-K76,K83-M99, N13.0-N13.5,N13.7-N13.9,N14,N15.0,N15.8-N15.9,N20-N23,N28-N39,N41-N64,N80-N98)'

                         ]
causes_of_death = causes_of_death[~causes_of_death['113 Cause Name'].isin(not_wanted_diseases_list)]
causes_of_death.shape
causes_of_death.to_csv("Leading_Causes_of_death.csv")

# %%
from datetime import datetime
from pyspark.sql.functions import col, udf
from pyspark.sql.types import DateType
# converting the date from string to DateTime format using UDF
func =  udf (lambda x: datetime.strptime(x, '%Y'), DateType())

# %%
import pyspark
from pyspark.sql import SQLContext
from pyspark import SparkContext
sc =SparkContext.getOrCreate()
sqlContext = SQLContext(sc)
df = sqlContext.read.csv("Leading_Causes_of_death.csv", header=True)
df = df.withColumn('Year', func(col('Year')))
df.printSchema()
df.registerTempTable("Death_data_Set")
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/context.py:113: FutureWarning:
#
# Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
# root
#  |-- _c0: string (nullable = true)
#  |-- Year: date (nullable = true)
#  |-- 113 Cause Name: string (nullable = true)
#  |-- Cause Name: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Deaths: string (nullable = true)
#  |-- Age-adjusted Death Rate: string (nullable = true)
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py:329: FutureWarning:
#
# Deprecated in 2.0, use createOrReplaceTempView instead.

# %%
death=sqlContext.sql("SELECT YEAR(Year) AS Years,`113 Cause Name`,State, Deaths FROM Death_data_Set ")

# %%
death.show()
death.registerTempTable("Death_dataset")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f9cf6d78e77a> in <cell line: 1>()
# ----> 1 death.show()
#       2 death.registerTempTable("Death_dataset")
#
# NameError: name 'death' is not defined

# %%
from pyspark.sql.types import IntegerType
death=death.withColumn("Years", death["Years"].cast(IntegerType()))

# %%
D=sqlContext.sql("SELECT  Years as Years,avg(CAST(Death_dataset.`Deaths` AS DOUBLE)) AS Deaths,State,`113 Cause Name` FROM Death_dataset GROUP BY  State,`113 Cause Name`, Years ORDER BY Years,State,Deaths")

# %%
D.registerTempTable("Disease")
D.describe()
# Out:
# DataFrame[summary: string, Years: string, Deaths: string, State: string, 113 Cause Name: string]

# %%
from pyspark.sql.types import DoubleType

D = D.withColumn("Deaths", D["Deaths"].cast(DoubleType()))

# %%
sqlContext.sql("SELECT * FROM Disease WHERE Deaths IS NOT NULL  GROUP BY `113 Cause Name`, Years,Deaths,State ORDER BY  Years, Deaths DESC").show(100)
# Out:
# +-----+--------+--------------+--------------------+
# |Years|  Deaths|         State|      113 Cause Name|
# +-----+--------+--------------+--------------------+
# | 1999|725192.0| United States|Diseases of heart...|
# | 1999|549838.0| United States|Malignant neoplas...|
# | 1999|167366.0| United States|Cerebrovascular d...|
# | 1999|124181.0| United States|Chronic lower res...|
# | 1999| 71930.0|    California|Diseases of heart...|
# | 1999| 68399.0| United States|Diabetes mellitus...|
# | 1999| 63730.0| United States|Influenza and pne...|
# | 1999| 58987.0|      New York|Diseases of heart...|
# | 1999| 53067.0|    California|Malignant neoplas...|
# | 1999| 51434.0|       Florida|Diseases of heart...|
# | 1999| 44536.0| United States|Alzheimer's disea...|
# | 1999| 43418.0|         Texas|Diseases of heart...|
# | 1999| 41707.0|  Pennsylvania|Diseases of heart...|
# | 1999| 38478.0|       Florida|Malignant neoplas...|
# | 1999| 37609.0|      New York|Malignant neoplas...|
# | 1999| 35525.0| United States|Nephritis, nephro...|
# | 1999| 33387.0|      Illinois|Diseases of heart...|
# | 1999| 33192.0|          Ohio|Diseases of heart...|
# | 1999| 32755.0|         Texas|Malignant neoplas...|
# | 1999| 30312.0|  Pennsylvania|Malignant neoplas...|
# | 1999| 27693.0|      Michigan|Diseases of heart...|
# | 1999| 25233.0|          Ohio|Malignant neoplas...|
# | 1999| 25024.0|      Illinois|Malignant neoplas...|
# | 1999| 23493.0|    New Jersey|Diseases of heart...|
# | 1999| 19744.0|      Michigan|Malignant neoplas...|
# | 1999| 19191.0|North Carolina|Diseases of heart...|
# | 1999| 18178.0|    New Jersey|Malignant neoplas...|
# | 1999| 17974.0|      Missouri|Diseases of heart...|
# | 1999| 17962.0|    California|Cerebrovascular d...|
# | 1999| 17597.0|       Georgia|Diseases of heart...|
# | 1999| 16661.0|       Indiana|Diseases of heart...|
# | 1999| 16280.0|     Tennessee|Diseases of heart...|
# | 1999| 15871.0| Massachusetts|Diseases of heart...|
# | 1999| 15815.0|North Carolina|Malignant neoplas...|
# | 1999| 15329.0|      Virginia|Diseases of heart...|
# | 1999| 13853.0| Massachusetts|Malignant neoplas...|
# | 1999| 13827.0|     Wisconsin|Diseases of heart...|
# | 1999| 13419.0|       Alabama|Diseases of heart...|
# | 1999| 13365.0|      Virginia|Malignant neoplas...|
# | 1999| 13225.0|       Georgia|Malignant neoplas...|
# | 1999| 13165.0|    California|Chronic lower res...|
# | 1999| 12898.0|       Indiana|Malignant neoplas...|
# | 1999| 12186.0|      Missouri|Malignant neoplas...|
# | 1999| 12098.0|      Kentucky|Diseases of heart...|
# | 1999| 12080.0|      Maryland|Diseases of heart...|
# | 1999| 12007.0|     Louisiana|Diseases of heart...|
# | 1999| 11943.0|     Tennessee|Malignant neoplas...|
# | 1999| 11515.0|    Washington|Diseases of heart...|
# | 1999| 11263.0|      Oklahoma|Diseases of heart...|
# | 1999| 10800.0|       Arizona|Diseases of heart...|
# | 1999| 10755.0|     Wisconsin|Malignant neoplas...|
# | 1999| 10653.0|    Washington|Malignant neoplas...|
# | 1999| 10560.0|       Florida|Cerebrovascular d...|
# | 1999| 10414.0|         Texas|Cerebrovascular d...|
# | 1999| 10143.0|      Maryland|Malignant neoplas...|
# | 1999|  9981.0|South Carolina|Diseases of heart...|
# | 1999|  9533.0|     Minnesota|Diseases of heart...|
# | 1999|  9506.0|       Alabama|Malignant neoplas...|
# | 1999|  9412.0|     Louisiana|Malignant neoplas...|
# | 1999|  9336.0|   Mississippi|Diseases of heart...|
# | 1999|  9131.0|       Florida|Chronic lower res...|
# | 1999|  9127.0|   Connecticut|Diseases of heart...|
# | 1999|  9006.0|       Arizona|Malignant neoplas...|
# | 1999|  8925.0|      Kentucky|Malignant neoplas...|
# | 1999|  8892.0|     Minnesota|Malignant neoplas...|
# | 1999|  8699.0|          Iowa|Diseases of heart...|
# | 1999|  8600.0|  Pennsylvania|Cerebrovascular d...|
# | 1999|  8315.0|      Arkansas|Diseases of heart...|
# | 1999|  8124.0|      New York|Cerebrovascular d...|
# | 1999|  8089.0|South Carolina|Malignant neoplas...|
# | 1999|  7714.0|      Illinois|Cerebrovascular d...|
# | 1999|  7518.0|         Texas|Chronic lower res...|
# | 1999|  7312.0|      Oklahoma|Malignant neoplas...|
# | 1999|  7263.0|        Oregon|Diseases of heart...|
# | 1999|  7235.0|          Ohio|Cerebrovascular d...|
# | 1999|  7086.0|      New York|Chronic lower res...|
# | 1999|  7054.0|   Connecticut|Malignant neoplas...|
# | 1999|  6975.0|        Kansas|Diseases of heart...|
# | 1999|  6905.0|        Oregon|Malignant neoplas...|
# | 1999|  6822.0| West Virginia|Diseases of heart...|
# | 1999|  6420.0|      Colorado|Diseases of heart...|
# | 1999|  6401.0|    California|Diabetes mellitus...|
# | 1999|  6346.0|          Iowa|Malignant neoplas...|
# | 1999|  6143.0|   Mississippi|Malignant neoplas...|
# | 1999|  6141.0|  Pennsylvania|Chronic lower res...|
# | 1999|  6137.0|      Arkansas|Malignant neoplas...|
# | 1999|  6041.0|      Michigan|Cerebrovascular d...|
# | 1999|  5863.0|      Colorado|Malignant neoplas...|
# | 1999|  5858.0|          Ohio|Chronic lower res...|
# | 1999|  5626.0|North Carolina|Cerebrovascular d...|
# | 1999|  5482.0|      New York|Influenza and pne...|
# | 1999|  5334.0|        Kansas|Malignant neoplas...|
# | 1999|  5155.0|      Illinois|Chronic lower res...|
# | 1999|  4931.0|         Texas|Diabetes mellitus...|
# | 1999|  4762.0| West Virginia|Malignant neoplas...|
# | 1999|  4560.0|    California|Influenza and pne...|
# | 1999|  4532.0|    California|Alzheimer's disea...|
# | 1999|  4497.0|      Nebraska|Diseases of heart...|
# | 1999|  4416.0|       Georgia|Cerebrovascular d...|
# | 1999|  4357.0|       Florida|Diabetes mellitus...|
# +-----+--------+--------------+--------------------+
# only showing top 100 rows

# %%
table=sqlContext.sql("SELECT * FROM Disease WHERE Deaths IS NOT NULL ORDER BY Deaths DESC")
table.registerTempTable("Death_Data_Set")

# %%
sqlContext.sql("SELECT MAX(Deaths) AS Max_Deaths,
`113 Cause Name` as Causes, Years, State
               From Death_Data_Set
               WHERE State != 'United States'
               GROUP BY  Years, `113 Cause Name`,
               State ORDER BY Years,MAX(Deaths) DESC").show(10)
# Out:
# +----------+--------------------+-----+------------+
# |Max_Deaths|              Causes|Years|       State|
# +----------+--------------------+-----+------------+
# |   71930.0|Diseases of heart...| 1999|  California|
# |   58987.0|Diseases of heart...| 1999|    New York|
# |   53067.0|Malignant neoplas...| 1999|  California|
# |   51434.0|Diseases of heart...| 1999|     Florida|
# |   43418.0|Diseases of heart...| 1999|       Texas|
# |   41707.0|Diseases of heart...| 1999|Pennsylvania|
# |   38478.0|Malignant neoplas...| 1999|     Florida|
# |   37609.0|Malignant neoplas...| 1999|    New York|
# |   33387.0|Diseases of heart...| 1999|    Illinois|
# |   33192.0|Diseases of heart...| 1999|        Ohio|
# +----------+--------------------+-----+------------+
# only showing top 10 rows

# %%
result=sqlContext.sql("SELECT MAX(Deaths) AS Max_Deaths,`113 Cause Name` as Causes, Years as Yearly, State From Death_Data_Set WHERE State != 'United States' GROUP BY  Years, `113 Cause Name`, State ORDER BY Years,MAX(Deaths) DESC")

# %%
from pyspark.sql.types import IntegerType
result=result.withColumn("Yearly", result["Yearly"].cast(IntegerType()))
result.registerTempTable("max_city_wise_death")

# %%
sqlContext.sql("SELECT Entire_Pollution.Yearly,max_city_wise_death.Max_Deaths, max_city_wise_death.Causes,max_city_wise_death.State,Entire_Pollution.City,Entire_Pollution.Max_NO2_AQI,Entire_Pollution.Max_SO2_AQI, Entire_Pollution.Max_CO_AQI,Entire_Pollution.MAX_O3_AQI FROM Entire_Pollution JOIN max_city_wise_death ON max_city_wise_death.State==Entire_Pollution.State AND Entire_Pollution.Yearly=max_city_wise_death.Yearly GROUP BY Entire_Pollution.Yearly,max_city_wise_death.State,Entire_Pollution.City,max_city_wise_death.Causes,max_city_wise_death.Max_Deaths, Entire_Pollution.Max_NO2_AQI,Entire_Pollution.Max_SO2_AQI, Entire_Pollution.Max_CO_AQI,Entire_Pollution.MAX_O3_AQI ORDER BY Entire_Pollution.Yearly ,max_city_wise_death.Max_Deaths DESC").show(100)
# Out:
# +------+----------+--------------------+--------------+--------------------+-----------+-----------+----------+----------+
# |Yearly|Max_Deaths|              Causes|         State|                City|Max_NO2_AQI|Max_SO2_AQI|Max_CO_AQI|MAX_O3_AQI|
# +------+----------+--------------------+--------------+--------------------+-----------+-----------+----------+----------+
# |  2000|   68426.0|Diseases of heart...|    California|Vandenberg Air Fo...|       31.0|        6.0|       6.0|      80.0|
# |  2000|   68426.0|Diseases of heart...|    California|         Victorville|       94.0|       36.0|      18.0|     179.0|
# |  2000|   68426.0|Diseases of heart...|    California|            Rubidoux|       94.0|      115.0|      48.0|     192.0|
# |  2000|   68426.0|Diseases of heart...|    California|             Concord|       72.0|       29.0|      31.0|     147.0|
# |  2000|   68426.0|Diseases of heart...|    California|       San Francisco|       72.0|       27.0|      36.0|      36.0|
# |  2000|   68426.0|Diseases of heart...|    California|              Goleta|       54.0|       13.0|      18.0|      74.0|
# |  2000|   68426.0|Diseases of heart...|    California|       Bethel Island|       41.0|       26.0|      17.0|     124.0|
# |  2000|   68426.0|Diseases of heart...|    California|          Long Beach|      108.0|       65.0|      63.0|     114.0|
# |  2000|   68426.0|Diseases of heart...|    California|       Not in a city|       84.0|       21.0|      35.0|     154.0|
# |  2000|   68426.0|Diseases of heart...|    California|           San Pablo|       64.0|       39.0|      22.0|      74.0|
# |  2000|   68426.0|Diseases of heart...|    California|           Davenport|       33.0|       33.0|       9.0|      47.0|
# |  2000|   68426.0|Diseases of heart...|    California|           Pittsburg|       51.0|       40.0|      28.0|     111.0|
# |  2000|   68426.0|Diseases of heart...|    California|        Arden-Arcade|       60.0|       33.0|      52.0|     161.0|
# |  2000|   68426.0|Diseases of heart...|    California|              Lompoc|       42.0|       10.0|      17.0|      74.0|
# |  2000|   68426.0|Diseases of heart...|    California|            Calexico|      118.0|       37.0|     201.0|     195.0|
# |  2000|   68426.0|Diseases of heart...|    California|             Vallejo|       62.0|       24.0|      57.0|      47.0|
# |  2000|   68426.0|Diseases of heart...|    California|           San Diego|      104.0|       79.0|      65.0|     109.0|
# |  2000|   68426.0|Diseases of heart...|    California|           Hawthorne|      106.0|      141.0|      77.0|     100.0|
# |  2000|   68426.0|Diseases of heart...|    California|          Costa Mesa|      102.0|       29.0|      69.0|     127.0|
# |  2000|   68426.0|Diseases of heart...|    California|         Los Angeles|      111.0|      100.0|      66.0|     169.0|
# |  2000|   68426.0|Diseases of heart...|    California|             Capitan|       52.0|       36.0|      10.0|     122.0|
# |  2000|   68426.0|Diseases of heart...|    California|         Chula Vista|       70.0|       62.0|      35.0|     104.0|
# |  2000|   68426.0|Diseases of heart...|    California|         Bakersfield|       88.0|       17.0|      43.0|      40.0|
# |  2000|   68426.0|Diseases of heart...|    California|             Burbank|      113.0|       14.0|      68.0|     202.0|
# |  2000|   57474.0|Diseases of heart...|      New York|          Holtsville|       67.0|       86.0|      32.0|     203.0|
# |  2000|   57474.0|Diseases of heart...|      New York|            New York|      101.0|      105.0|      55.0|     201.0|
# |  2000|   53158.0|Malignant neoplas...|    California|Vandenberg Air Fo...|       31.0|        6.0|       6.0|      80.0|
# |  2000|   53158.0|Malignant neoplas...|    California|         Victorville|       94.0|       36.0|      18.0|     179.0|
# |  2000|   53158.0|Malignant neoplas...|    California|            Rubidoux|       94.0|      115.0|      48.0|     192.0|
# |  2000|   53158.0|Malignant neoplas...|    California|             Concord|       72.0|       29.0|      31.0|     147.0|
# |  2000|   53158.0|Malignant neoplas...|    California|       San Francisco|       72.0|       27.0|      36.0|      36.0|
# |  2000|   53158.0|Malignant neoplas...|    California|              Goleta|       54.0|       13.0|      18.0|      74.0|
# |  2000|   53158.0|Malignant neoplas...|    California|       Bethel Island|       41.0|       26.0|      17.0|     124.0|
# |  2000|   53158.0|Malignant neoplas...|    California|          Long Beach|      108.0|       65.0|      63.0|     114.0|
# |  2000|   53158.0|Malignant neoplas...|    California|       Not in a city|       84.0|       21.0|      35.0|     154.0|
# |  2000|   53158.0|Malignant neoplas...|    California|           San Pablo|       64.0|       39.0|      22.0|      74.0|
# |  2000|   53158.0|Malignant neoplas...|    California|           Davenport|       33.0|       33.0|       9.0|      47.0|
# |  2000|   53158.0|Malignant neoplas...|    California|           Pittsburg|       51.0|       40.0|      28.0|     111.0|
# |  2000|   53158.0|Malignant neoplas...|    California|        Arden-Arcade|       60.0|       33.0|      52.0|     161.0|
# |  2000|   53158.0|Malignant neoplas...|    California|              Lompoc|       42.0|       10.0|      17.0|      74.0|
# |  2000|   53158.0|Malignant neoplas...|    California|            Calexico|      118.0|       37.0|     201.0|     195.0|
# |  2000|   53158.0|Malignant neoplas...|    California|             Vallejo|       62.0|       24.0|      57.0|      47.0|
# |  2000|   53158.0|Malignant neoplas...|    California|           San Diego|      104.0|       79.0|      65.0|     109.0|
# |  2000|   53158.0|Malignant neoplas...|    California|           Hawthorne|      106.0|      141.0|      77.0|     100.0|
# |  2000|   53158.0|Malignant neoplas...|    California|          Costa Mesa|      102.0|       29.0|      69.0|     127.0|
# |  2000|   53158.0|Malignant neoplas...|    California|         Los Angeles|      111.0|      100.0|      66.0|     169.0|
# |  2000|   53158.0|Malignant neoplas...|    California|             Capitan|       52.0|       36.0|      10.0|     122.0|
# |  2000|   53158.0|Malignant neoplas...|    California|         Chula Vista|       70.0|       62.0|      35.0|     104.0|
# |  2000|   53158.0|Malignant neoplas...|    California|         Bakersfield|       88.0|       17.0|      43.0|      40.0|
# |  2000|   53158.0|Malignant neoplas...|    California|             Burbank|      113.0|       14.0|      68.0|     202.0|
# |  2000|   50336.0|Diseases of heart...|       Florida|         Winter Park|       71.0|       82.0|      53.0|     150.0|
# |  2000|   43020.0|Diseases of heart...|         Texas|             Houston|      101.0|      172.0|      42.0|     203.0|
# |  2000|   43020.0|Diseases of heart...|         Texas|              Dallas|       97.0|       19.0|      25.0|     177.0|
# |  2000|   43020.0|Diseases of heart...|         Texas|             El Paso|       99.0|       50.0|      49.0|     154.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|                York|       63.0|      104.0|      22.0|     177.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|        Freemansburg|       44.0|       59.0|      26.0|     201.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|          Greensburg|       49.0|      110.0|      17.0|     145.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|          Norristown|       64.0|       44.0|      16.0|     207.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|           Lancaster|       55.0|       79.0|      19.0|     177.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|          Pittsburgh|       74.0|      117.0|      18.0|     169.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|             Reading|       57.0|      135.0|      22.0|     172.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|          New Castle|       65.0|      124.0|      19.0|     100.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|           Charleroi|       43.0|      110.0|      11.0|     169.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|           Johnstown|       50.0|      110.0|      16.0|     156.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|             Altoona|       61.0|       69.0|      11.0|     151.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|        Beaver Falls|       74.0|      104.0|      11.0|     161.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|             Bristol|       64.0|       82.0|      19.0|     207.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|            Scranton|       70.0|       62.0|      16.0|     159.0|
# |  2000|   40708.0|Diseases of heart...|  Pennsylvania|        Philadelphia|       95.0|       89.0|      51.0|     140.0|
# |  2000|   39183.0|Malignant neoplas...|       Florida|         Winter Park|       71.0|       82.0|      53.0|     150.0|
# |  2000|   37198.0|Malignant neoplas...|      New York|          Holtsville|       67.0|       86.0|      32.0|     203.0|
# |  2000|   37198.0|Malignant neoplas...|      New York|            New York|      101.0|      105.0|      55.0|     201.0|
# |  2000|   33300.0|Malignant neoplas...|         Texas|             Houston|      101.0|      172.0|      42.0|     203.0|
# |  2000|   33300.0|Malignant neoplas...|         Texas|              Dallas|       97.0|       19.0|      25.0|     177.0|
# |  2000|   33300.0|Malignant neoplas...|         Texas|             El Paso|       99.0|       50.0|      49.0|     154.0|
# |  2000|   31844.0|Diseases of heart...|      Illinois|             Chicago|       97.0|      102.0|      26.0|      42.0|
# |  2000|   31844.0|Diseases of heart...|      Illinois|              Cicero|       84.0|       79.0|      38.0|      87.0|
# |  2000|   31844.0|Diseases of heart...|      Illinois|Calumet City (PU ...|       58.0|      136.0|      24.0|     101.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|          Norristown|       64.0|       44.0|      16.0|     207.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|             Reading|       57.0|      135.0|      22.0|     172.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|          New Castle|       65.0|      124.0|      19.0|     100.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|           Lancaster|       55.0|       79.0|      19.0|     177.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|           Charleroi|       43.0|      110.0|      11.0|     169.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|                York|       63.0|      104.0|      22.0|     177.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|          Pittsburgh|       74.0|      117.0|      18.0|     169.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|           Johnstown|       50.0|      110.0|      16.0|     156.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|        Freemansburg|       44.0|       59.0|      26.0|     201.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|             Altoona|       61.0|       69.0|      11.0|     151.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|          Greensburg|       49.0|      110.0|      17.0|     145.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|        Beaver Falls|       74.0|      104.0|      11.0|     161.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|             Bristol|       64.0|       82.0|      19.0|     207.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|            Scranton|       70.0|       62.0|      16.0|     159.0|
# |  2000|   30161.0|Malignant neoplas...|  Pennsylvania|        Philadelphia|       95.0|       89.0|      51.0|     140.0|
# |  2000|   27325.0|Diseases of heart...|      Michigan|             Detroit|       93.0|      134.0|      51.0|     114.0|
# |  2000|   25365.0|Malignant neoplas...|      Illinois|             Chicago|       97.0|      102.0|      26.0|      42.0|
# |  2000|   25365.0|Malignant neoplas...|      Illinois|              Cicero|       84.0|       79.0|      38.0|      87.0|
# |  2000|   25365.0|Malignant neoplas...|      Illinois|Calumet City (PU ...|       58.0|      136.0|      24.0|     101.0|
# |  2000|   23724.0|Diseases of heart...|    New Jersey|              Camden|       97.0|       91.0|      51.0|     203.0|
# |  2000|   19798.0|Malignant neoplas...|      Michigan|             Detroit|       93.0|      134.0|      51.0|     114.0|
# |  2000|   19723.0|Diseases of heart...|North Carolina|           Charlotte|       74.0|       92.0|      42.0|     205.0|
# +------+----------+--------------------+--------------+--------------------+-----------+-----------+----------+----------+
# only showing top 100 rows

# %%
Pollution_wise_Death=sqlContext.sql("SELECT Entire_Pollution.Yearly,max_city_wise_death.Max_Deaths, max_city_wise_death.Causes,max_city_wise_death.State,Entire_Pollution.City,Entire_Pollution.Max_NO2_AQI,Entire_Pollution.Max_SO2_AQI, Entire_Pollution.Max_CO_AQI,Entire_Pollution.MAX_O3_AQI FROM Entire_Pollution JOIN max_city_wise_death ON max_city_wise_death.State==Entire_Pollution.State AND Entire_Pollution.Yearly=max_city_wise_death.Yearly GROUP BY Entire_Pollution.Yearly,max_city_wise_death.State,Entire_Pollution.City,max_city_wise_death.Causes,max_city_wise_death.Max_Deaths, Entire_Pollution.Max_NO2_AQI,Entire_Pollution.Max_SO2_AQI, Entire_Pollution.Max_CO_AQI,Entire_Pollution.MAX_O3_AQI ORDER BY Entire_Pollution.Yearly ,max_city_wise_death.Max_Deaths DESC")
Pollution_wise_Death.toPandas().to_csv("Pollution_wise_Death.csv")
